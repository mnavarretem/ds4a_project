# %%
#!pip install translate

# %%
# Load packages
import nltk # imports the natural language toolkit
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import string
import re
from collections import Counter
from nltk.stem import PorterStemmer
from nltk.util import ngrams
from pylab import rcParams
from wordcloud import WordCloud
import nltk
import os

from translate import Translator

# %%
data_responses = pd.read_csv('SentiWordNet.csv', sep='\t')
data_responses = data_responses[(data_responses['PosScore'] > 0) | (data_responses['NegScore'] > 0) ]
data_responses
# Out:
#        POS       ID  PosScore  NegScore  \
# 0        a     1740     0.125     0.000
# 1        a     2098     0.000     0.750
# 10       a     3700     0.250     0.000
# 11       a     3829     0.250     0.000
# 20       a     5107     0.500     0.000
# ...     ..      ...       ...       ...
# 117651   v  2771169     0.125     0.000
# 117652   v  2771320     0.000     0.250
# 117655   v  2771888     0.000     0.125
# 117657   v  2772202     0.125     0.250
# 117658   v  2772310     0.125     0.000
#
#                                      SynsetTerms  \
# 0                                         able#1
# 1                                       unable#1
# 10                                  dissilient#1
# 11                                  parturient#2
# 20                         uncut#7 full-length#2
# ...                                          ...
# 117651  light_up#3 clear_up#4 clear#3 brighten#2
# 117652                         plague#1 blight#1
# 117655                                  fog_up#1
# 117657                                    haze#1
# 117658                              deflagrate#1
#
#                                                     Gloss
# 0       (usually followed by `to') having the necessar...
# 1       (usually followed by `to') not having the nece...
# 10      bursting open with force, as do some ripe seed...
# 11                    giving birth; "a parturient heifer"
# 20                       complete; "the full-length play"
# ...                                                   ...
# 117651    become clear; "The sky cleared after the storm"
# 117652  cause to suffer a blight; "Too much rain may b...
# 117655              get foggy; "The windshield fogged up"
# 117657                       become hazy, dull, or cloudy
# 117658  cause to burn rapidly and with great intensity...
#
# [29095 rows x 6 columns]

# %%
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('_', ' ', regex=False)
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('#', ',', regex=False)
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('\d+', '', regex=True)
data_selected = data_responses['SynsetTerms'].reset_index(drop = True)
data_selected
len(data_selected['SynsetTerms'])
# Out:
# 29095

# %%
translated_ls = []
translator    = Translator(to_lang="Spanish")
text_ls       = data_selected


for idx in range(7232,len(text_ls)):
    translation = translator.translate(text_ls.iloc[idx])
    translated_ls.append(translation)
    print('translating: {0:2.2f}% --> '.format(100 * idx/len(text_ls))+translation)
    
#translation = translator.translate('light up, clear up, clear, brighten,')
#print(translation)
# Out:
# translating: 23.39% --> turbulento, tumultuoso, atribulado, desenfrenado, perturbador,
# translating: 23.40% --> chillones
# translating: 23.40% --> Random
# translating: 23.40% --> acertar o fallar, azaroso,
# translating: 23.41% --> no aleatorio,
# translating: 23.41% --> deliberado,
# translating: 23.41% --> racional
# translating: 23.42% --> lúcido, lógico, coherente,
# translating: 23.42% --> pensando, razonando, inteligente,
# translating: 23.42% --> cuerdo, razonable,
# translating: 23.43% --> Irracional
# translating: 23.43% --> irracional, ciego,
# translating: 23.43% --> sin razón
# translating: 23.44% --> irracional,
# translating: 23.44% --> supersticioso.
# translating: 23.44% --> emocionalmente
# translating: 23.45% --> intelectual, cerebral,
# translating: 23.45% --> Multirracial
# translating: 23.45% --> racista
# translating: 23.46% --> oxidable,
# translating: 23.46% --> inestable
# translating: 23.46% --> inactiva
# translating: 23.47% --> neutral, inerte, indiferente,
# translating: 23.47% --> hidalgo
# translating: 23.47% --> table
# translating: 23.48% --> A la orden
# translating: 23.48% --> listo, preparado, en forma,
# translating: 23.49% --> \"indicador, mensaje\"
# translating: 23.49% --> maduro
# translating: 23.49% --> esperando, listo y esperando,
# translating: 23.50% --> no preparado,
# translating: 23.50% --> arco vencido
# translating: 23.50% --> desprevenido, desprevenido, desprevenido, desprevenido, desprevenido, desprevenido, durmiendo,
# translating: 23.51% --> verde
# translating: 23.51% --> real
# translating: 23.51% --> factual, actual,
# translating: 23.52% --> objetivo, documental,
# translating: 23.52% --> irreal
# translating: 23.52% --> soñado
# translating: 23.53% --> visualizado, visualizado, representado, imaginado,
# translating: 23.53% --> trampantojo, engañoso a la vista,
# translating: 23.53% --> legendario, legendario,
# translating: 23.54% --> mitológico, mitológico, mítico, mítico, fabuloso,
# translating: 23.54% --> imaginario, imaginario, fantasioso,
# translating: 23.54% --> fantástico, fantástico,
# translating: 23.55% --> alucinatorio
# translating: 23.55% --> ilusorio, ilusorio,
# translating: 23.55% --> ilusorio, ilusorio,
# translating: 23.56% --> fingir, fingir,
# translating: 23.56% --> cruceiro
# translating: 23.56% --> adecuado
# translating: 23.57% --> irreal
# translating: 23.57% --> engañoso, engañoso,
# translating: 23.57% --> surrealista, onírico,
# translating: 23.58% --> phantom
# translating: 23.58% --> realista
# translating: 23.58% --> terrenal, realista,
# translating: 23.59% --> vívido, pictórico, realista, gráfico,
# translating: 23.59% --> sala de estar
# translating: 23.60% --> verídico, real,
# translating: 23.60% --> virtual, practico,
# translating: 23.60% --> poco realista,
# translating: 23.61% --> Quimera
# translating: 23.61% --> falso, engañoso,
# translating: 23.61% --> salvaje, fantástico,
# translating: 23.62% --> Franz Kafka
# translating: 23.62% --> surrealista, surrealista, fantasmagórico, fantasmagórico,
# translating: 23.62% --> sensato, razonable,
# translating: 23.63% --> sentido común, sentido común, sentido común,
# translating: 23.63% --> sano, sensato, sensato, inteligente, sano,
# translating: 23.63% --> abusivo
# translating: 23.64% --> en contra del razonamiento
# translating: 23.64% --> insostenible, indefendible,
# translating: 23.64% --> sin sentido, sin razón, sin sentido,
# translating: 23.65% --> injustificado, injustificado, indebido,
# translating: 23.65% --> bilateral,
# translating: 23.65% --> trilateral,
# translating: 23.66% --> correlativo
# translating: 23.66% --> interactivo, interaccional,
# translating: 23.66% --> no recíproco,
# translating: 23.67% --> no recíproco,
# translating: 23.67% --> no correspondido, no correspondido, sin respuesta,
# translating: 23.67% --> refinado
# translating: 23.68% --> Cortés, gentil, culto, culto, civilizado, civilizado,
# translating: 23.68% --> COUTH
# translating: 23.68% --> twee, remilgado, niminy-piminy, picado, delicado,
# translating: 23.69% --> suave, elegante, elegante, elegante,
# translating: 23.69% --> fina, delicada,
# translating: 23.69% --> caballeroso, caballeroso,
# translating: 23.70% --> Elegante
# translating: 23.70% --> superfino, demasiado refinado,
# translating: 23.71% --> educado, educado,
# translating: 23.71% --> sin refinado
# translating: 23.71% --> Weeds
# translating: 23.72% --> inculto, inculto, sin arte,
# translating: 23.72% --> porcino, patán, neandertal, neandertal, patán, grosero,
# translating: 23.72% --> vulgar, tosco, tosco, vulgar, tosco,
# translating: 23.73% --> espeso
# translating: 23.73% --> yokelish, underbreed, rudo, lowbred, mal educado, libertino,
# translating: 23.73% --> baja,
# translating: 23.74% --> robusto
# translating: 23.74% --> basto
# translating: 23.74% --> áspero
# translating: 23.75% --> poco caballeroso, poco caballeroso,
# translating: 23.75% --> vulgar,
# translating: 23.75% --> vulcanizado, vulcanizado, curado,
# translating: 23.76% --> semiprocesado,
# translating: 23.76% --> No elaborado
# translating: 23.76% --> sin vulcanizar, sin vulcanizar,
# translating: 23.77% --> refinado, procesado,
# translating: 23.77% --> sin refinar, sin procesar, crudo,
# translating: 23.77% --> activado,
# translating: 23.78% --> Dopaje
# translating: 23.78% --> Examinado
# translating: 23.78% --> sin tratar
# translating: 23.79% --> raw
# translating: 23.79% --> lubrificado
# translating: 23.79% --> sin limpiar
# translating: 23.80% --> tratado
# translating: 23.80% --> atado, vendado,
# translating: 23.80% --> Dosed
# translating: 23.81% --> sin tratar
# translating: 23.81% --> repercutibles
# translating: 23.82% --> recobrable
# translating: 23.82% --> irrecuperable, irrecuperable,
# translating: 23.82% --> irrecuperable, irrecuperable,
# translating: 23.83% --> perdidos,
# translating: 23.83% --> regenerar
# translating: 23.83% --> renacido, convertido, nacido de nuevo,
# translating: 23.84% --> Reformada
# translating: 23.84% --> no regenerado, no regenerado,
# translating: 23.84% --> impenitente, obstinado, obstinado, maldecido,
# translating: 23.85% --> impenitente
# translating: 23.85% --> no persuadido, inconverso,
# translating: 23.85% --> no registrado
# translating: 23.86% --> no cotizado en bolsa
# translating: 23.86% --> no registrado
# translating: 23.86% --> prescrito, oficial,
# translating: 23.87% --> homogénea,
# translating: 23.87% --> débil
# translating: 23.87% --> bien ordenado
# translating: 23.88% --> Poco frecuente
# translating: 23.88% --> torcido, asimétrico,
# translating: 23.88% --> ilegal, no convencional, inadecuado,
# translating: 23.89% --> fuerte
# translating: 23.89% --> regulado,
# translating: 23.89% --> Irremediable.
# translating: 23.90% --> no renovable, no renovable,
# translating: 23.90% --> arrendable,
# translating: 23.90% --> no alquilable,
# translating: 23.91% --> reparable, rectificable,
# translating: 23.91% --> mantenible,
# translating: 23.91% --> irreparable
# translating: 23.92% --> irrepetible, indescriptible,
# translating: 23.92% --> repetitivo, repetitivo,
# translating: 23.93% --> reiterativo, iterativo,
# translating: 23.93% --> no repetitivo,
# translating: 23.93% --> Imprimible
# translating: 23.94% --> indecente,
# translating: 23.94% --> no solicitado
# translating: 23.94% --> no solicitado, no solicitado,
# translating: 23.95% --> sin rima, sin rima, sin rima, sin rima,
# translating: 23.95% --> invariable, uniforme,
# translating: 23.95% --> multiforme
# translating: 23.96% --> polimorfo, polimórfico,
# translating: 23.96% --> cíclico
# translating: 23.96% --> Trianual
# translating: 23.97% --> no cíclico
# translating: 23.97% --> no oscilatorio
# translating: 23.97% --> posición corporal no reclinada
# translating: 23.98% --> Poco frecuente
# translating: 23.98% --> no relacionado
# translating: 23.98% --> desconectado
# translating: 23.99% --> connatos, afines,
# translating: 23.99% --> no relacionado
# translating: 23.99% --> ortogonal
# translating: 24.00% --> aplicable
# translating: 24.00% --> hidruro de germanio
# translating: 24.00% --> pertinente
# translating: 24.01% --> no hace al caso
# translating: 24.01% --> tangencial, digresivo,
# translating: 24.01% --> ortogonal, impertinente, inmaterial, ajena,
# translating: 24.02% --> inadecuado, inaplicable,
# translating: 24.02% --> discutible
# translating: 24.02% --> consciente, consciente,
# translating: 24.03% --> atento, cuidadoso,
# translating: 24.03% --> inconsciente, inconsciente, olvidadizo,
# translating: 24.04% --> amnésico, amnésico,
# translating: 24.04% --> Fuente lumiosa:
# translating: 24.04% --> estandarizado, estandarizado, similar, intercambiable, intercambiable,
# translating: 24.05% --> insustituible, insustituible,
# translating: 24.05% --> representativo, delineativo,
# translating: 24.05% --> Mimesis
# translating: 24.06% --> realista, naturalista,
# translating: 24.06% --> geométrico, geométrico,
# translating: 24.06% --> Hierático
# translating: 24.07% --> semiabstracto,
# translating: 24.07% --> no simbólico, no representativo,
# translating: 24.07% --> respetado
# translating: 24.08% --> prestigioso, honrado, estimado,
# translating: 24.08% --> respetable, honorable, bueno, estimable,
# translating: 24.08% --> temible
# translating: 24.09% --> bien pensado, respetado,
# translating: 24.09% --> Desacreditado
# translating: 24.09% --> deshonroso
# translating: 24.10% --> desacreditado, dañado,
# translating: 24.10% --> notorio, infame, de mala fama,
# translating: 24.10% --> sombrío, louche,
# translating: 24.11% --> escuálido, sórdido, sórdido, sórdido, sórdido,
# translating: 24.11% --> receptivo, abierto,
# translating: 24.11% --> aceptante
# translating: 24.12% --> admisible,
# translating: 24.12% --> asimilativo
# translating: 24.12% --> Hospitalidad
# translating: 24.13% --> poco receptivo
# translating: 24.13% --> antipático, cerrado,
# translating: 24.13% --> reconciliable
# translating: 24.14% --> armonizable,
# translating: 24.14% --> Solución
# translating: 24.15% --> irreconciliable, irreconciliable,
# translating: 24.15% --> hostil
# translating: 24.15% --> inconsistente
# translating: 24.16% --> reservado
# translating: 24.16% --> al otro lado del escenario, distante, distante,
# translating: 24.16% --> Timidez
# translating: 24.17% --> retirado
# translating: 24.17% --> sin reserva
# translating: 24.17% --> sin reserva
# translating: 24.18% --> prisa, por orden de llegada,
# translating: 24.18% --> no tomado antes,
# translating: 24.18% --> resistible,
# translating: 24.19% --> irresistible, irresistible,
# translating: 24.19% --> abrumador, abrumador,
# translating: 24.19% --> resolutivos
# translating: 24.20% --> decidido
# translating: 24.20% --> vida o muerte, desesperada,
# translating: 24.20% --> inquebrantable, inquebrantable, inquebrantable, inflexible, rígido, estable, firme, firme,
# translating: 24.21% --> cuadrado
# translating: 24.21% --> empeñado,
# translating: 24.21% --> Espartano
# translating: 24.22% --> robusto, incondicional,
# translating: 24.22% --> imperturbable, imperturbable, imperturbable,
# translating: 24.22% --> sin desanimarse, sin inmutarse,
# translating: 24.23% --> desanimado
# translating: 24.23% --> débil
# translating: 24.23% --> inestable
# translating: 24.24% --> vacilante, vacilante, vacilante,
# translating: 24.24% --> de rodillas débiles
# translating: 24.24% --> respetable
# translating: 24.25% --> agradable, decente,
# translating: 24.25% --> Presentable
# translating: 24.26% --> irrespetuoso,
# translating: 24.26% --> respetuoso
# translating: 24.26% --> respetuoso, deferente, deferente,
# translating: 24.27% --> honorífico
# translating: 24.27% --> irrespetuoso
# translating: 24.27% --> desdeñoso, insultante, desdeñoso, despectivo,
# translating: 24.28% --> contumelioso,
# translating: 24.28% --> burlarse, burlarse, burlarse, burlona, burlona,
# translating: 24.28% --> deshonroso, impío,
# translating: 24.29% --> mocoso, insolente, insolente, flip,
# translating: 24.29% --> indeferencial
# translating: 24.29% --> responsable
# translating: 24.30% --> responsable,
# translating: 24.30% --> dócil
# translating: 24.30% --> responsable
# translating: 24.31% --> irresponsable
# translating: 24.31% --> slaphappy, harum-scarum, happy-go-lucky, freewheeling, devil-may-care, despreocupado,
# translating: 24.31% --> No hacer nada.
# translating: 24.32% --> irresponsable,
# translating: 24.32% --> suelto, inactivo,
# translating: 24.32% --> violento
# translating: 24.33% --> inexplicable
# translating: 24.33% --> poco fiable
# translating: 24.33% --> c. sensible
# translating: 24.34% --> encuestado, respondiendo,
# translating: 24.34% --> sin respuesta
# translating: 24.34% --> intratable
# translating: 24.35% --> Cerrar
# translating: 24.35% --> tenue, discreto, discreto,
# translating: 24.35% --> poco expansivo
# translating: 24.36% --> libre
# translating: 24.36% --> arrogante, exuberante, extravagante, excesivo,
# translating: 24.37% --> marcha por efecto fuerza
# translating: 24.37% --> alto vuelo
# translating: 24.37% --> desenfrenado, desenfrenado, desenfrenado, desenfrenado,
# translating: 24.38% --> desabrochado, desabrochado,
# translating: 24.38% --> sin obstáculos, sin obstáculos,
# translating: 24.38% --> con restricción
# translating: 24.39% --> limitado, circunscrito,
# translating: 24.39% --> cerrado
# translating: 24.39% --> sin restricciones
# translating: 24.40% --> todo tiempo
# translating: 24.40% --> discrecional
# translating: 24.40% --> abierto
# translating: 24.41% --> Mandato de duración indefinida
# translating: 24.41% --> suntuario,
# translating: 24.41% --> supresor
# translating: 24.42% --> irrestricto,
# translating: 24.42% --> emancipador,
# translating: 24.42% --> no restrictivo,
# translating: 24.43% --> tenaz, retentiva, recoleta, larga,
# translating: 24.43% --> irreflexivo, breve, olvidadizo,
# translating: 24.43% --> entrecruzado, entrecruzado,
# translating: 24.44% --> weblike, webby, palmeado, enredado, netlike, encaje,
# translating: 24.44% --> Mashhad
# translating: 24.44% --> no reticulado,
# translating: 24.45% --> RETRACTIL
# translating: 24.45% --> retráctil,
# translating: 24.45% --> no retráctil, no retráctil,
# translating: 24.46% --> reflexivo
# translating: 24.46% --> especular, similar a un espejo,
# translating: 24.46% --> reflexionar
# translating: 24.47% --> no reflectante, no reflectante,
# translating: 24.47% --> sin eco
# translating: 24.47% --> irreflexivo
# translating: 24.48% --> brillante, brillante,
# translating: 24.48% --> live
# translating: 24.49% --> reverberante, reverberante, resonante, resonante, resonante,
# translating: 24.49% --> dinámico
# translating: 24.49% --> irreverberante, no resonante,
# translating: 24.50% --> anecoico
# translating: 24.50% --> muerto
# translating: 24.50% --> sordo, sordo,
# translating: 24.51% --> reverente
# translating: 24.51% --> adorador, adorador,
# translating: 24.51% --> horrible, asombrado,
# translating: 24.52% --> venerador, reverencial, respetuoso,
# translating: 24.52% --> irreverente
# translating: 24.52% --> sacrílego, profano, blasfemo,
# translating: 24.53% --> irrespetuoso, sin miedo, sin miedo,
# translating: 24.53% --> reanimado
# translating: 24.53% --> recrudescente,
# translating: 24.54% --> renovado
# translating: 24.54% --> resurgente, renaciente,
# translating: 24.54% --> resucitado,
# translating: 24.55% --> revitalizado, revitalizado,
# translating: 24.55% --> no revivido, no renovado,
# translating: 24.55% --> estimulado
# translating: 24.56% --> Despierto
# translating: 24.56% --> asombrado, asombrado, asombrado,
# translating: 24.56% --> intimidado,
# translating: 24.57% --> soltera
# translating: 24.57% --> sin miedo, sin miedo,
# translating: 24.57% --> contrarrevolucionario,
# translating: 24.58% --> favorecido,
# translating: 24.58% --> gratificante
# translating: 24.58% --> poco gratificante
# translating: 24.59% --> desagradecido, desagradecido, desagradecido,
# translating: 24.59% --> infructuoso
# translating: 24.60% --> retórico
# translating: 24.60% --> turgente, tumid, orotund, grande, declamatorio, grandilocuente,
# translating: 24.60% --> adornado, florido,
# translating: 24.61% --> púrpura, adornado en exceso, empurpled,
# translating: 24.61% --> medicolegal
# translating: 24.61% --> alto, grandilocuente, grandilocuente,
# translating: 24.62% --> oratorio,
# translating: 24.62% --> poco retórico
# translating: 24.62% --> prosaico, práctico,
# translating: 24.63% --> rítmico, rítmico,
# translating: 24.63% --> cadencia, cadencia,
# translating: 24.63% --> danceable.
# translating: 24.64% --> Jazz
# translating: 24.64% --> tropezar, swingy, balanceo, cadencioso,
# translating: 24.64% --> sáfico,
# translating: 24.65% --> cantar, entonar, cantar,
# translating: 24.65% --> Síncopa
# translating: 24.65% --> palpitante
# translating: 24.66% --> no rítmico, no rítmico,
# translating: 24.66% --> arrítmico, arrítmico,
# translating: 24.66% --> no rítmico
# translating: 24.67% --> desmedido
# translating: 24.67% --> en forma de costilla
# translating: 24.67% --> sin costillas
# translating: 24.68% --> rico, adinerado, cargado, rasante, rico,
# translating: 24.68% --> acomodado, bien situado, acomodado, acomodado, bien arreglado, próspero, fácil, cómodo,
# translating: 24.68% --> pedregoso, pedregoso, piel, busto, roto,
# translating: 24.69% --> empobrecido, necesitado, necesitado, indigente, empobrecido, desamparado,
# translating: 24.69% --> pellizcado, miserable, sin un centavo, en circunstancias difíciles, pobre, duro,
# translating: 24.69% --> Moneyless
# translating: 24.70% --> no provisto
# translating: 24.70% --> rico
# translating: 24.71% --> mal
# translating: 24.71% --> sin recursos,
# translating: 24.71% --> rico
# translating: 24.72% --> suntuoso, principesco, opulento, lujoso, grandioso, dorado, de lujo,
# translating: 24.72% --> felpa, felpa, exuberante, lucullan, lujoso,
# translating: 24.72% --> mal
# translating: 24.73% --> significa, mendigo,
# translating: 24.73% --> SLUMMY
# translating: 24.73% --> adinerado, adinerado,
# translating: 24.74% --> Moneyless
# translating: 24.74% --> disolvente,
# translating: 24.74% --> insolvente
# translating: 24.75% --> panza arriba, en bancarrota,
# translating: 24.75% --> esbelto
# translating: 24.75% --> penetración anal con lengua
# translating: 24.76% --> borde rojo,
# translating: 24.76% --> Sin armazón
# translating: 24.76% --> sin manos
# translating: 24.77% --> a dos manos, ambidiestro,
# translating: 24.77% --> equilibrado
# translating: 24.77% --> conservador
# translating: 24.78% --> reaccionario, reaccionario, de extrema derecha,
# translating: 24.78% --> a la derecha
# translating: 24.78% --> Extremo izquierdo
# translating: 24.79% --> izquierdoso,
# translating: 24.79% --> en medio del camino, centrista,
# translating: 24.79% --> más a la derecha,
# translating: 24.80% --> con forma de cuerno
# translating: 24.80% --> cuernos huecos
# translating: 24.80% --> córneo
# translating: 24.81% --> sea correcta,
# translating: 24.81% --> honorable, honorable, ético,
# translating: 24.82% --> incorrecto
# translating: 24.82% --> vicioso, reprensible, deplorable, criminal, condenable,
# translating: 24.82% --> inmoral, bajo,
# translating: 24.83% --> equivocado, equivocado,
# translating: 24.83% --> esta vez.
# translating: 24.83% --> en posición vertical, solo, bien,
# translating: 24.84% --> el sonido,
# translating: 24.84% --> injusto
# translating: 24.84% --> malvado, impío, pecador,
# translating: 24.85% --> robusto
# translating: 24.85% --> pecho grande, pecho grande,
# translating: 24.85% --> de hombros cuadrados, de hombros anchos, de hombros grandes,
# translating: 24.86% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 40 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.86% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.86% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.87% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 38 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.87% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 38 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.87% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 37 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.88% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 37 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.88% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 36 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.88% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 35 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 35 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 34 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 34 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 33 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 32 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 32 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 31 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 31 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 30 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 29 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 29 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 28 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 27 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 27 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 25 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 24 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 24 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 23 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 23 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 22 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 21 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 19 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 24.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 12 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 12 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 11 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.06% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.06% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 01 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.06% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.07% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 49 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.07% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.07% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 53 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 53 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 52 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.11% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 52 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.11% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 51 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.11% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 50 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.12% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 49 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.12% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 49 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.12% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 48 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.13% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 47 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.13% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 47 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.13% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 46 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.14% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 46 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.14% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 45 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.15% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 44 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.15% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 43 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.15% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 42 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.16% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 41 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.16% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 40 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.16% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 40 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.17% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.17% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.17% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 38 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.18% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 37 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.18% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 37 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.18% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 36 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.19% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 36 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.19% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 35 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.19% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 35 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.20% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 34 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.20% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 32 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.20% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 32 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.21% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 31 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.21% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 31 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.21% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 29 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.22% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 29 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.22% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 28 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.22% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 27 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.23% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 26 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.23% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 26 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.23% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 25 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.24% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 24 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.24% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 23 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.24% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 23 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.25% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 22 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.25% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 22 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.26% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 21 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.26% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.26% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.27% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 19 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.27% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 19 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.27% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.28% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.28% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.28% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.29% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.29% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.29% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.30% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.30% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.30% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.31% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 48 MINUTES 12 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# ...
# translating: 25.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 24 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 24 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 23 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 23 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 22 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 21 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 21 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 12 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 11 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 25.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 46 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 26.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 45 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-144-efd0452dbb77> in <module>
#       5
#       6 for idx in range(6806,len(text_ls)):
# ----> 7     translation = translator.translate(text_ls.iloc[idx])
#       8     translated_ls.append(translation)
#       9     print('translating: {0:2.2f}% --> '.format(100 * idx/len(text_ls))+translation)
#
# ~\Anaconda3\lib\site-packages\translate\translate.py in translate(self, text)
#      40
#      41         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 42         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~\Anaconda3\lib\site-packages\translate\translate.py in <genexpr>(.0)
#      40
#      41         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 42         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~\Anaconda3\lib\site-packages\translate\providers\mymemory_translated.py in get_translation(self, text)
#      40
#      41     def get_translation(self, text):
# ---> 42         data = self._make_request(text)
#      43
#      44         translation = data['responseData']['translatedText']
#
# ~\Anaconda3\lib\site-packages\translate\providers\mymemory_translated.py in _make_request(self, text)
#      36             params['de'] = self.email
#      37
# ---> 38         response = requests.get(self.base_url, params=params, headers=self.headers)
#      39         return response.json()
#      40
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
translated_ls[0:426]
# Out:
# ['turbulento, tumultuoso, atribulado, desenfrenado, perturbador,',
#  'chillones',
#  'Random',
#  'acertar o fallar, azaroso,',
#  'no aleatorio,',
#  'deliberado,',
#  'racional',
#  'lúcido, lógico, coherente,',
#  'pensando, razonando, inteligente,',
#  'cuerdo, razonable,',
#  'Irracional',
#  'irracional, ciego,',
#  'sin razón',
#  'irracional,',
#  'supersticioso.',
#  'emocionalmente',
#  'intelectual, cerebral,',
#  'Multirracial',
#  'racista',
#  'oxidable,',
#  'inestable',
#  'inactiva',
#  'neutral, inerte, indiferente,',
#  'hidalgo',
#  'table',
#  'A la orden',
#  'listo, preparado, en forma,',
#  '\\"indicador, mensaje\\"',
#  'maduro',
#  'esperando, listo y esperando,',
#  'no preparado,',
#  'arco vencido',
#  'desprevenido, desprevenido, desprevenido, desprevenido, desprevenido, desprevenido, durmiendo,',
#  'verde',
#  'real',
#  'factual, actual,',
#  'objetivo, documental,',
#  'irreal',
#  'soñado',
#  'visualizado, visualizado, representado, imaginado,',
#  'trampantojo, engañoso a la vista,',
#  'legendario, legendario,',
#  'mitológico, mitológico, mítico, mítico, fabuloso,',
#  'imaginario, imaginario, fantasioso,',
#  'fantástico, fantástico,',
#  'alucinatorio',
#  'ilusorio, ilusorio,',
#  'ilusorio, ilusorio,',
#  'fingir, fingir,',
#  'cruceiro',
#  'adecuado',
#  'irreal',
#  'engañoso, engañoso,',
#  'surrealista, onírico,',
#  'phantom',
#  'realista',
#  'terrenal, realista,',
#  'vívido, pictórico, realista, gráfico,',
#  'sala de estar',
#  'verídico, real,',
#  'virtual, practico,',
#  'poco realista,',
#  'Quimera',
#  'falso, engañoso,',
#  'salvaje, fantástico,',
#  'Franz Kafka',
#  'surrealista, surrealista, fantasmagórico, fantasmagórico,',
#  'sensato, razonable,',
#  'sentido común, sentido común, sentido común,',
#  'sano, sensato, sensato, inteligente, sano,',
#  'abusivo',
#  'en contra del razonamiento',
#  'insostenible, indefendible,',
#  'sin sentido, sin razón, sin sentido,',
#  'injustificado, injustificado, indebido,',
#  'bilateral,',
#  'trilateral,',
#  'correlativo',
#  'interactivo, interaccional,',
#  'no recíproco,',
#  'no recíproco,',
#  'no correspondido, no correspondido, sin respuesta,',
#  'refinado',
#  'Cortés, gentil, culto, culto, civilizado, civilizado,',
#  'COUTH',
#  'twee, remilgado, niminy-piminy, picado, delicado,',
#  'suave, elegante, elegante, elegante,',
#  'fina, delicada,',
#  'caballeroso, caballeroso,',
#  'Elegante',
#  'superfino, demasiado refinado,',
#  'educado, educado,',
#  'sin refinado',
#  'Weeds',
#  'inculto, inculto, sin arte,',
#  'porcino, patán, neandertal, neandertal, patán, grosero,',
#  'vulgar, tosco, tosco, vulgar, tosco,',
#  'espeso',
#  'yokelish, underbreed, rudo, lowbred, mal educado, libertino,',
#  'baja,',
#  'robusto',
#  'basto',
#  'áspero',
#  'poco caballeroso, poco caballeroso,',
#  'vulgar,',
#  'vulcanizado, vulcanizado, curado,',
#  'semiprocesado,',
#  'No elaborado',
#  'sin vulcanizar, sin vulcanizar,',
#  'refinado, procesado,',
#  'sin refinar, sin procesar, crudo,',
#  'activado,',
#  'Dopaje',
#  'Examinado',
#  'sin tratar',
#  'raw',
#  'lubrificado',
#  'sin limpiar',
#  'tratado',
#  'atado, vendado,',
#  'Dosed',
#  'sin tratar',
#  'repercutibles',
#  'recobrable',
#  'irrecuperable, irrecuperable,',
#  'irrecuperable, irrecuperable,',
#  'perdidos,',
#  'regenerar',
#  'renacido, convertido, nacido de nuevo,',
#  'Reformada',
#  'no regenerado, no regenerado,',
#  'impenitente, obstinado, obstinado, maldecido,',
#  'impenitente',
#  'no persuadido, inconverso,',
#  'no registrado',
#  'no cotizado en bolsa',
#  'no registrado',
#  'prescrito, oficial,',
#  'homogénea,',
#  'débil',
#  'bien ordenado',
#  'Poco frecuente',
#  'torcido, asimétrico,',
#  'ilegal, no convencional, inadecuado,',
#  'fuerte',
#  'regulado,',
#  'Irremediable.',
#  'no renovable, no renovable,',
#  'arrendable,',
#  'no alquilable,',
#  'reparable, rectificable,',
#  'mantenible,',
#  'irreparable',
#  'irrepetible, indescriptible,',
#  'repetitivo, repetitivo,',
#  'reiterativo, iterativo,',
#  'no repetitivo,',
#  'Imprimible',
#  'indecente,',
#  'no solicitado',
#  'no solicitado, no solicitado,',
#  'sin rima, sin rima, sin rima, sin rima,',
#  'invariable, uniforme,',
#  'multiforme',
#  'polimorfo, polimórfico,',
#  'cíclico',
#  'Trianual',
#  'no cíclico',
#  'no oscilatorio',
#  'posición corporal no reclinada',
#  'Poco frecuente',
#  'no relacionado',
#  'desconectado',
#  'connatos, afines,',
#  'no relacionado',
#  'ortogonal',
#  'aplicable',
#  'hidruro de germanio',
#  'pertinente',
#  'no hace al caso',
#  'tangencial, digresivo,',
#  'ortogonal, impertinente, inmaterial, ajena,',
#  'inadecuado, inaplicable,',
#  'discutible',
#  'consciente, consciente,',
#  'atento, cuidadoso,',
#  'inconsciente, inconsciente, olvidadizo,',
#  'amnésico, amnésico,',
#  'Fuente lumiosa:',
#  'estandarizado, estandarizado, similar, intercambiable, intercambiable,',
#  'insustituible, insustituible,',
#  'representativo, delineativo,',
#  'Mimesis',
#  'realista, naturalista,',
#  'geométrico, geométrico,',
#  'Hierático',
#  'semiabstracto,',
#  'no simbólico, no representativo,',
#  'respetado',
#  'prestigioso, honrado, estimado,',
#  'respetable, honorable, bueno, estimable,',
#  'temible',
#  'bien pensado, respetado,',
#  'Desacreditado',
#  'deshonroso',
#  'desacreditado, dañado,',
#  'notorio, infame, de mala fama,',
#  'sombrío, louche,',
#  'escuálido, sórdido, sórdido, sórdido, sórdido,',
#  'receptivo, abierto,',
#  'aceptante',
#  'admisible,',
#  'asimilativo',
#  'Hospitalidad',
#  'poco receptivo',
#  'antipático, cerrado,',
#  'reconciliable',
#  'armonizable,',
#  'Solución',
#  'irreconciliable, irreconciliable,',
#  'hostil',
#  'inconsistente',
#  'reservado',
#  'al otro lado del escenario, distante, distante,',
#  'Timidez',
#  'retirado',
#  'sin reserva',
#  'sin reserva',
#  'prisa, por orden de llegada,',
#  'no tomado antes,',
#  'resistible,',
#  'irresistible, irresistible,',
#  'abrumador, abrumador,',
#  'resolutivos',
#  'decidido',
#  'vida o muerte, desesperada,',
#  'inquebrantable, inquebrantable, inquebrantable, inflexible, rígido, estable, firme, firme,',
#  'cuadrado',
#  'empeñado,',
#  'Espartano',
#  'robusto, incondicional,',
#  'imperturbable, imperturbable, imperturbable,',
#  'sin desanimarse, sin inmutarse,',
#  'desanimado',
#  'débil',
#  'inestable',
#  'vacilante, vacilante, vacilante,',
#  'de rodillas débiles',
#  'respetable',
#  'agradable, decente,',
#  'Presentable',
#  'irrespetuoso,',
#  'respetuoso',
#  'respetuoso, deferente, deferente,',
#  'honorífico',
#  'irrespetuoso',
#  'desdeñoso, insultante, desdeñoso, despectivo,',
#  'contumelioso,',
#  'burlarse, burlarse, burlarse, burlona, burlona,',
#  'deshonroso, impío,',
#  'mocoso, insolente, insolente, flip,',
#  'indeferencial',
#  'responsable',
#  'responsable,',
#  'dócil',
#  'responsable',
#  'irresponsable',
#  'slaphappy, harum-scarum, happy-go-lucky, freewheeling, devil-may-care, despreocupado,',
#  'No hacer nada.',
#  'irresponsable,',
#  'suelto, inactivo,',
#  'violento',
#  'inexplicable',
#  'poco fiable',
#  'c. sensible',
#  'encuestado, respondiendo,',
#  'sin respuesta',
#  'intratable',
#  'Cerrar',
#  'tenue, discreto, discreto,',
#  'poco expansivo',
#  'libre',
#  'arrogante, exuberante, extravagante, excesivo,',
#  'marcha por efecto fuerza',
#  'alto vuelo',
#  'desenfrenado, desenfrenado, desenfrenado, desenfrenado,',
#  'desabrochado, desabrochado,',
#  'sin obstáculos, sin obstáculos,',
#  'con restricción',
#  'limitado, circunscrito,',
#  'cerrado',
#  'sin restricciones',
#  'todo tiempo',
#  'discrecional',
#  'abierto',
#  'Mandato de duración indefinida',
#  'suntuario,',
#  'supresor',
#  'irrestricto,',
#  'emancipador,',
#  'no restrictivo,',
#  'tenaz, retentiva, recoleta, larga,',
#  'irreflexivo, breve, olvidadizo,',
#  'entrecruzado, entrecruzado,',
#  'weblike, webby, palmeado, enredado, netlike, encaje,',
#  'Mashhad',
#  'no reticulado,',
#  'RETRACTIL',
#  'retráctil,',
#  'no retráctil, no retráctil,',
#  'reflexivo',
#  'especular, similar a un espejo,',
#  'reflexionar',
#  'no reflectante, no reflectante,',
#  'sin eco',
#  'irreflexivo',
#  'brillante, brillante,',
#  'live',
#  'reverberante, reverberante, resonante, resonante, resonante,',
#  'dinámico',
#  'irreverberante, no resonante,',
#  'anecoico',
#  'muerto',
#  'sordo, sordo,',
#  'reverente',
#  'adorador, adorador,',
#  'horrible, asombrado,',
#  'venerador, reverencial, respetuoso,',
#  'irreverente',
#  'sacrílego, profano, blasfemo,',
#  'irrespetuoso, sin miedo, sin miedo,',
#  'reanimado',
#  'recrudescente,',
#  'renovado',
#  'resurgente, renaciente,',
#  'resucitado,',
#  'revitalizado, revitalizado,',
#  'no revivido, no renovado,',
#  'estimulado',
#  'Despierto',
#  'asombrado, asombrado, asombrado,',
#  'intimidado,',
#  'soltera',
#  'sin miedo, sin miedo,',
#  'contrarrevolucionario,',
#  'favorecido,',
#  'gratificante',
#  'poco gratificante',
#  'desagradecido, desagradecido, desagradecido,',
#  'infructuoso',
#  'retórico',
#  'turgente, tumid, orotund, grande, declamatorio, grandilocuente,',
#  'adornado, florido,',
#  'púrpura, adornado en exceso, empurpled,',
#  'medicolegal',
#  'alto, grandilocuente, grandilocuente,',
#  'oratorio,',
#  'poco retórico',
#  'prosaico, práctico,',
#  'rítmico, rítmico,',
#  'cadencia, cadencia,',
#  'danceable.',
#  'Jazz',
#  'tropezar, swingy, balanceo, cadencioso,',
#  'sáfico,',
#  'cantar, entonar, cantar,',
#  'Síncopa',
#  'palpitante',
#  'no rítmico, no rítmico,',
#  'arrítmico, arrítmico,',
#  'no rítmico',
#  'desmedido',
#  'en forma de costilla',
#  'sin costillas',
#  'rico, adinerado, cargado, rasante, rico,',
#  'acomodado, bien situado, acomodado, acomodado, bien arreglado, próspero, fácil, cómodo,',
#  'pedregoso, pedregoso, piel, busto, roto,',
#  'empobrecido, necesitado, necesitado, indigente, empobrecido, desamparado,',
#  'pellizcado, miserable, sin un centavo, en circunstancias difíciles, pobre, duro,',
#  'Moneyless',
#  'no provisto',
#  'rico',
#  'mal',
#  'sin recursos,',
#  'rico',
#  'suntuoso, principesco, opulento, lujoso, grandioso, dorado, de lujo,',
#  'felpa, felpa, exuberante, lucullan, lujoso,',
#  'mal',
#  'significa, mendigo,',
#  'SLUMMY',
#  'adinerado, adinerado,',
#  'Moneyless',
#  'disolvente,',
#  'insolvente',
#  'panza arriba, en bancarrota,',
#  'esbelto',
#  'penetración anal con lengua',
#  'borde rojo,',
#  'Sin armazón',
#  'sin manos',
#  'a dos manos, ambidiestro,',
#  'equilibrado',
#  'conservador',
#  'reaccionario, reaccionario, de extrema derecha,',
#  'a la derecha',
#  'Extremo izquierdo',
#  'izquierdoso,',
#  'en medio del camino, centrista,',
#  'más a la derecha,',
#  'con forma de cuerno',
#  'cuernos huecos',
#  'córneo',
#  'sea correcta,',
#  'honorable, honorable, ético,',
#  'incorrecto',
#  'vicioso, reprensible, deplorable, criminal, condenable,',
#  'inmoral, bajo,',
#  'equivocado, equivocado,',
#  'esta vez.',
#  'en posición vertical, solo, bien,',
#  'el sonido,',
#  'injusto',
#  'malvado, impío, pecador,',
#  'robusto',
#  'pecho grande, pecho grande,',
#  'de hombros cuadrados, de hombros anchos, de hombros grandes,']

# %%
translated_ls = translated_ls[0:426]
len(translated_ls)
row_list = range(6806,(6806+426))

df = pd.DataFrame(data=translated_ls, index=row_list)
df
# Out:
#                                                       0
# 6806  turbulento, tumultuoso, atribulado, desenfrena...
# 6807                                          chillones
# 6808                                             Random
# 6809                         acertar o fallar, azaroso,
# 6810                                      no aleatorio,
# ...                                                 ...
# 7227                                            injusto
# 7228                           malvado, impío, pecador,
# 7229                                            robusto
# 7230                        pecho grande, pecho grande,
# 7231  de hombros cuadrados, de hombros anchos, de ho...
#
# [426 rows x 1 columns]

# %%
save_file = 'words_to_translate_2'
save_path = os.path.join(save_file + '.csv')
df.to_csv(save_path)
