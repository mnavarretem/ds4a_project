# %%
#!pip install translate

# %%
# Load packages
import nltk # imports the natural language toolkit
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import string
import re
from collections import Counter
from nltk.stem import PorterStemmer
from nltk.util import ngrams
from pylab import rcParams
from wordcloud import WordCloud
import nltk
import os

from translate import Translator

# %%
data_responses = pd.read_csv('SentiWordNet.csv', sep='\t')
data_responses = data_responses[(data_responses['PosScore'] > 0) | (data_responses['NegScore'] > 0) ]
data_responses
# Out:
#        POS       ID  PosScore  NegScore  \
# 0        a     1740     0.125     0.000
# 1        a     2098     0.000     0.750
# 10       a     3700     0.250     0.000
# 11       a     3829     0.250     0.000
# 20       a     5107     0.500     0.000
# ...     ..      ...       ...       ...
# 117651   v  2771169     0.125     0.000
# 117652   v  2771320     0.000     0.250
# 117655   v  2771888     0.000     0.125
# 117657   v  2772202     0.125     0.250
# 117658   v  2772310     0.125     0.000
#
#                                      SynsetTerms  \
# 0                                         able#1
# 1                                       unable#1
# 10                                  dissilient#1
# 11                                  parturient#2
# 20                         uncut#7 full-length#2
# ...                                          ...
# 117651  light_up#3 clear_up#4 clear#3 brighten#2
# 117652                         plague#1 blight#1
# ...

# %%
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('_', ' ', regex=False)
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('#', ',', regex=False)
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('\d+', '', regex=True)
data_responses
# Out:
#        POS       ID  PosScore  NegScore                           SynsetTerms  \
# 0        a     1740     0.125     0.000                                 able,
# 1        a     2098     0.000     0.750                               unable,
# 10       a     3700     0.250     0.000                           dissilient,
# 11       a     3829     0.250     0.000                           parturient,
# 20       a     5107     0.500     0.000                   uncut, full-length,
# ...     ..      ...       ...       ...                                   ...
# 117651   v  2771169     0.125     0.000  light up, clear up, clear, brighten,
# 117652   v  2771320     0.000     0.250                       plague, blight,
# 117655   v  2771888     0.000     0.125                               fog up,
# 117657   v  2772202     0.125     0.250                                 haze,
# 117658   v  2772310     0.125     0.000                           deflagrate,
#
# ...

# %%
data_selected = data_responses['SynsetTerms'].reset_index(drop = True)
data_selected
len(data_selected)
# Out:
# 29095

# %%
translated_ls = []
translator    = Translator(to_lang="Spanish")
text_ls       = data_selected
start_at      = 8983


for idx in range(start_at,len(text_ls)):
    translation = translator.translate(text_ls.iloc[idx])
    translated_ls.append(translation)
    print('translating: {0:2.2f}% --> '.format(100 * idx/len(text_ls))+translation)
    
#translation = translator.translate('light up, clear up, clear, brighten,')
#print(translation)
# Out:
# translating: 29.28% --> robusto, rico, picante, con cuerpo,
# translating: 29.28% --> picante
# translating: 29.28% --> con sabor a jengibre
# translating: 29.29% --> grapy, uva,
# translating: 29.29% --> ágil,
# translating: 29.29% --> nuez, como nuez,
# translating: 29.30% --> picante, picante, sabroso, sabroso, picante,
# translating: 29.30% --> picante, acre,
# translating: 29.30% --> salada
# translating: 29.31% --> مه آلود
# translating: 29.31% --> agria
# translating: 29.31% --> de sabor fuerte,
# translating: 29.32% --> winy, winey,
# translating: 29.32% --> insípido
# translating: 29.32% --> Insípido, insípido, insípido, insípido, insípido, insípido, plano, insípido,
# translating: 29.33% --> sin sabor, sin sabor, sin sabor, sin sabor,
# translating: 29.33% --> sin condimentar, sin sal,
# translating: 29.33% --> Evaluable
# translating: 29.34% --> no tributable, exento,
# translating: 29.34% --> libre de impuestos
# translating: 29.35% --> templado
# ...

# %%
total_ok = 465
translated_ls[0:total_ok]
# Out:
# ['robusto, rico, picante, con cuerpo,',
#  'picante',
#  'con sabor a jengibre',
#  'grapy, uva,',
#  'ágil,',
#  'nuez, como nuez,',
#  'picante, picante, sabroso, sabroso, picante,',
#  'picante, acre,',
#  'salada',
#  'مه آلود',
#  'agria',
#  'de sabor fuerte,',
#  'winy, winey,',
#  'insípido',
#  'Insípido, insípido, insípido, insípido, insípido, insípido, plano, insípido,',
#  'sin sabor, sin sabor, sin sabor, sin sabor,',
#  'sin condimentar, sin sal,',
#  'Evaluable',
#  'no tributable, exento,',
#  'libre de impuestos',
#  'templado',
#  'ligero, abstemio,',
#  'sobrio, moderado,',
#  'inmoderado',
#  'pesado, grande,',
#  'templado',
#  'templado frío',
#  'ecuánime,',
#  'inmoderado',
#  'laxo',
#  'flacidez, caída, caída,',
#  'limp',
#  'flojo, suelto,',
#  'articulaciones sueltas',
#  'sin tensión,',
#  'suspenso, suspenso, morderse las uñas, colgar del acantilado,',
#  'tenso',
#  'picazón, inquietud, inquietud, ansiedad,',
#  'NERVIOSISMO',
#  'Desgarre muscular',
# ...

# %%
translated_ls = translated_ls[0:total_ok]
row_list = range(start_at, (start_at + total_ok))

df = pd.DataFrame(data=translated_ls, index=row_list)
df
# Out:
#                                         0
# 8518  robusto, rico, picante, con cuerpo,
# 8519                              picante
# 8520                 con sabor a jengibre
# 8521                          grapy, uva,
# 8522                                ágil,
# ...                                   ...
# 8978                           en peligro
# 8979                         indefendible
# 8980                  inseguro, inseguro,
# 8981                          penetrable,
# 8982                          lo amenazó,
#
# [465 rows x 1 columns]

# %%
save_file = 'words_to_translate_2'
save_path = os.path.join(save_file + '.csv')
df.to_csv(save_path)
