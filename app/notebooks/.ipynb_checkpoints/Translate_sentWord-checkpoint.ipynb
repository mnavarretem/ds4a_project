# %% [markdown]
# This notebook is used to translate words from SentiWordNet.csv to spanish

# %% [markdown]
# #!pip install translate

# %%
# Load packages
import nltk # imports the natural language toolkit
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import string
import re
from collections import Counter
from nltk.stem import PorterStemmer
from nltk.util import ngrams
from pylab import rcParams
from wordcloud import WordCloud
import nltk
import os

from translate import Translator

# %%
data_responses = pd.read_csv('SentiWordNet.csv', sep='\t')
data_responses = data_responses[(data_responses['PosScore'] > 0) | (data_responses['NegScore'] > 0) ]
data_responses
# Out:
#        POS       ID  PosScore  NegScore  \
# 0        a     1740     0.125     0.000
# 1        a     2098     0.000     0.750
# 10       a     3700     0.250     0.000
# 11       a     3829     0.250     0.000
# 20       a     5107     0.500     0.000
# ...     ..      ...       ...       ...
# 117651   v  2771169     0.125     0.000
# 117652   v  2771320     0.000     0.250
# 117655   v  2771888     0.000     0.125
# 117657   v  2772202     0.125     0.250
# 117658   v  2772310     0.125     0.000
#
#                                      SynsetTerms  \
# 0                                         able#1
# 1                                       unable#1
# 10                                  dissilient#1
# 11                                  parturient#2
# 20                         uncut#7 full-length#2
# ...                                          ...
# 117651  light_up#3 clear_up#4 clear#3 brighten#2
# 117652                         plague#1 blight#1
# 117655                                  fog_up#1
# 117657                                    haze#1
# 117658                              deflagrate#1
#
#                                                     Gloss
# 0       (usually followed by `to') having the necessar...
# 1       (usually followed by `to') not having the nece...
# 10      bursting open with force, as do some ripe seed...
# 11                    giving birth; "a parturient heifer"
# 20                       complete; "the full-length play"
# ...                                                   ...
# 117651    become clear; "The sky cleared after the storm"
# 117652  cause to suffer a blight; "Too much rain may b...
# 117655              get foggy; "The windshield fogged up"
# 117657                       become hazy, dull, or cloudy
# 117658  cause to burn rapidly and with great intensity...
#
# [29095 rows x 6 columns]

# %%
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('_', ' ', regex=False)
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('#', ',', regex=False)
data_responses['SynsetTerms'] = data_responses['SynsetTerms'].str.replace('\d+', '', regex=True)
data_responses
# Out:
#        POS       ID  PosScore  NegScore                           SynsetTerms  \
# 0        a     1740     0.125     0.000                                 able,
# 1        a     2098     0.000     0.750                               unable,
# 10       a     3700     0.250     0.000                           dissilient,
# 11       a     3829     0.250     0.000                           parturient,
# 20       a     5107     0.500     0.000                   uncut, full-length,
# ...     ..      ...       ...       ...                                   ...
# 117651   v  2771169     0.125     0.000  light up, clear up, clear, brighten,
# 117652   v  2771320     0.000     0.250                       plague, blight,
# 117655   v  2771888     0.000     0.125                               fog up,
# 117657   v  2772202     0.125     0.250                                 haze,
# 117658   v  2772310     0.125     0.000                           deflagrate,
#
#                                                     Gloss
# 0       (usually followed by `to') having the necessar...
# 1       (usually followed by `to') not having the nece...
# 10      bursting open with force, as do some ripe seed...
# 11                    giving birth; "a parturient heifer"
# 20                       complete; "the full-length play"
# ...                                                   ...
# 117651    become clear; "The sky cleared after the storm"
# 117652  cause to suffer a blight; "Too much rain may b...
# 117655              get foggy; "The windshield fogged up"
# 117657                       become hazy, dull, or cloudy
# 117658  cause to burn rapidly and with great intensity...
#
# [29095 rows x 6 columns]

# %%
data_selected = data_responses['SynsetTerms'].reset_index(drop = True)
data_selected
len(data_selected)
# Out:
# 29095

# %%
translated_ls = []
translator    = Translator(to_lang="Spanish")
text_ls       = data_selected
start_at      = 8983


for idx in range(start_at,len(text_ls)):
    translation = translator.translate(text_ls.iloc[idx])
    translated_ls.append(translation)
    print('translating: {0:2.2f}% --> '.format(100 * idx/len(text_ls))+translation)
    
#translation = translator.translate('light up, clear up, clear, brighten,')
#print(translation)
# Out:
# translating: 30.87% --> bajo fuego, bajo ataque,
# translating: 30.88% --> indefenso
# translating: 30.88% --> Vulnerable
# translating: 30.89% --> hermético, hermético al aire,
# translating: 30.89% --> a prueba de bombas, a prueba de bombas,
# translating: 30.89% --> defendible, defendible,
# translating: 30.90% --> inatacable, inexpugnable, fuerte, seguro, inviolable, inexpugnable,
# translating: 30.90% --> Apretado
# translating: 30.90% --> Protegidas
# translating: 30.91% --> oprimido
# translating: 30.91% --> se busca
# translating: 30.91% --> deseado, anhelado,
# translating: 30.92% --> chaud
# translating: 30.92% --> anhelado, deseado, anhelado,
# translating: 30.92% --> buscado, buscado,
# translating: 30.93% --> No deseado
# translating: 30.93% --> abdicable
# translating: 30.93% --> paria, sin casta,
# translating: 30.94% --> fuera de lugar,
# translating: 30.94% --> no reclamado
# translating: 30.94% --> no buscado, no deseado,
# translating: 30.95% --> no deseado, no deseado, no deseado,
# translating: 30.95% --> cálido
# translating: 30.95% --> tibio, tibio,
# translating: 30.96% --> calentado
# translating: 30.96% --> frío
# translating: 30.96% --> programa de llamada
# translating: 30.97% --> cálido
# translating: 30.97% --> jarabe de fruta
# translating: 30.97% --> Abundante
# translating: 30.98% --> frío
# translating: 30.98% --> sin respuesta
# translating: 30.98% --> frío
# translating: 30.99% --> Sangre fría
# translating: 30.99% --> afectuoso
# translating: 31.00% --> corazón frío,
# translating: 31.00% --> curso frágil
# translating: 31.00% --> lavable
# translating: 31.01% --> lavado y uso, secado por goteo,
# translating: 31.01% --> no lavable,
# translating: 31.01% --> Encerado
# translating: 31.02% --> sin cera
# translating: 31.02% --> acelerador, acelerador,
# translating: 31.02% --> acrecionario
# translating: 31.03% --> acumulativo
# translating: 31.03% --> maximizando, maximizando,
# translating: 31.03% --> Con ajuste multiplicativo
# translating: 31.04% --> maximización de beneficios, maximización de beneficios,
# translating: 31.04% --> levantamiento
# translating: 31.04% --> disminuyendo
# translating: 31.05% --> depreciativo, depreciativo, depreciativo,
# translating: 31.05% --> detractor,
# translating: 31.05% --> disminuido
# translating: 31.06% --> caídas
# translating: 31.06% --> allargando,
# translating: 31.06% --> inflacionario
# translating: 31.07% --> Deflación
# translating: 31.07% --> lactante
# translating: 31.07% --> dispositivo de vestir
# translating: 31.08% --> inservible
# translating: 31.08% --> invadido por las malas hierbas
# translating: 31.08% --> deshierbe
# translating: 31.09% --> Bienvenido,
# translating: 31.09% --> mal acogido
# translating: 31.09% --> Uninvited
# translating: 31.10% --> bueno,
# translating: 31.10% --> asintomático, asintomático,
# translating: 31.11% --> recuperado, curado, curado,
# translating: 31.11% --> enfermo
# translating: 31.11% --> herido, afligido,
# translating: 31.12% --> angustia
# translating: 31.12% --> malestar, mal tiempo, enfermizo, cutre, mal, puntiagudo, indispuesto, enfermo,
# translating: 31.12% --> mareado, mareado, mareado, mareado,
# translating: 31.13% --> Autismo Infantil
# translating: 31.13% --> enfermo en cama, postrado en cama, postrado en cama, postrado en cama,
# translating: 31.13% --> librea, hígado, bilioso,
# translating: 31.14% --> bronquítico,
# translating: 31.14% --> tísico
# translating: 31.14% --> en recuperación, convaleciente,
# translating: 31.15% --> alucinante, delirante,
# translating: 31.15% --> diabético
# translating: 31.15% --> mareado, vertiginoso, mareado, mareado,
# translating: 31.16% --> Dispepsia
# translating: 31.16% --> desmayo, aturdimiento, aturdimiento, ligero, débil,
# translating: 31.16% --> febril, febril,
# translating: 31.17% --> divertido
# translating: 31.17% --> gotoso,
# translating: 31.17% --> verde
# translating: 31.18% --> Establecidas
# translating: 31.18% --> enfermizo, enfermo, mareado, con náuseas, náuseas,
# translating: 31.18% --> PARALISIS
# translating: 31.19% --> paralizado, paralítico,
# translating: 31.19% --> parapléjico
# translating: 31.19% --> desvencijado, raquítico,
# translating: 31.20% --> Escrófula
# translating: 31.20% --> Mocoso
# translating: 31.20% --> espástico
# translating: 31.21% --> tuberculoso, tuberculoso,
# translating: 31.21% --> sin curar
# translating: 31.21% --> apretar permanentemente
# translating: 31.22% --> húmedo, húmedo,
# translating: 31.22% --> empapado, empapado,
# translating: 31.23% --> húmedo
# translating: 31.23% --> pegajoso, humeante, bochornoso,
# translating: 31.23% --> enlodado
# translating: 31.24% --> lluvioso, lluvioso,
# translating: 31.24% --> pegajoso
# translating: 31.24% --> Lavado
# translating: 31.25% --> seco
# translating: 31.25% --> Al sol, chamuscado, reseco, horneado, adust,
# translating: 31.25% --> secado al aire
# translating: 31.26% --> seco al aire
# translating: 31.26% --> seco, árido,
# translating: 31.26% --> completamente seco, completamente seco,
# translating: 31.27% --> seco, desecado,
# translating: 31.27% --> secadas;
# translating: 31.27% --> sin lluvia,
# translating: 31.28% --> semiseco
# translating: 31.28% --> sediento
# translating: 31.28% --> mojado, lactante,
# translating: 31.29% --> seco
# translating: 31.29% --> seco
# translating: 31.29% --> sobre ruedas
# translating: 31.30% --> sin ruedas
# translating: 31.30% --> manual
# translating: 31.30% --> sano
# translating: 31.31% --> Nutritivo, nutritivo, nutritivo, nutritivo, alimentario, alimentario,
# translating: 31.31% --> ¿SALUDABLE PARA EL CORAZÓN?
# translating: 31.31% --> saludable, saludable, bueno para ti,
# translating: 31.32% --> sustancial, cuadrado, sólido, satisfactorio, abundante,
# translating: 31.32% --> orgánico
# translating: 31.32% --> salubre
# translating: 31.33% --> malsano
# translating: 31.33% --> insalubre, insalubre, insalubre,
# translating: 31.34% --> mezquino, insustancial,
# translating: 31.34% --> mórbido
# translating: 31.34% --> vil, repugnante, mareado, ofensivo, repugnante, nauseabundo, nauseabundo, repugnante,
# translating: 31.35% --> ancho, amplio,
# translating: 31.35% --> radiante
# translating: 31.35% --> de ala ancha,
# translating: 31.36% --> como un abanico
# translating: 31.36% --> estrecho
# translating: 31.36% --> estrechamiento, constricción, constricción,
# translating: 31.37% --> angosto
# translating: 31.37% --> microhyla
# translating: 31.37% --> delgado, delgado,
# translating: 31.38% --> estrecho
# translating: 31.38% --> afilado, afilado, estrechamiento,
# translating: 31.38% --> ancho
# translating: 31.39% --> es cómodo
# translating: 31.39% --> estrecho
# translating: 31.39% --> marginal, desnudo,
# translating: 31.40% --> manejable,
# translating: 31.40% --> inmanejable, inmanejable,
# translating: 31.40% --> torpe, torpe, torpe, torpe,
# translating: 31.41% --> engorroso, engorroso,
# translating: 31.41% --> peluca
# translating: 31.41% --> sin peluca
# translating: 31.42% --> dispuesto (hallazgo)
# translating: 31.42% --> Consentimiento
# translating: 31.42% --> preparado, inclinado, dispuesto, dispuesto,
# translating: 31.43% --> feliz, contento,
# translating: 31.43% --> listo
# translating: 31.43% --> estar dispuesto y ser capaz
# translating: 31.44% --> reacio
# translating: 31.44% --> reacio, loth, repugnante,
# translating: 31.45% --> involuntario, involuntario,
# translating: 31.45% --> en forma de ala, aliforme, alary, alar,
# translating: 31.45% --> de alas delgadas
# translating: 31.46% --> sin alas,
# translating: 31.46% --> aptero, apteral,
# translating: 31.46% --> no volador
# translating: 31.47% --> sabio,
# translating: 31.47% --> omnisciente, omnisciente,
# translating: 31.47% --> sapiente, sagaz, perspicaz,
# translating: 31.48% --> de búho,
# translating: 31.48% --> sapiencial,
# translating: 31.48% --> salvia
# translating: 31.49% --> tonto
# translating: 31.49% --> ridículo, ridículo, disparatado, ridículo, ridículo, idiota, irrisorio, loco, absurdo,
# translating: 31.49% --> vacío, insensato, estúpido, fatuo, estúpido,
# translating: 31.50% --> chiflado, chiflado, chiflado, tonto, cursi, tonto, chiflado, chiflado,
# translating: 31.50% --> enamorado
# translating: 31.50% --> loco, loco, descabellado,
# translating: 31.51% --> equivocado, mal concebido,
# translating: 31.51% --> espantoso, despistado, rattlepated, rattlebrained,
# translating: 31.51% --> imprudente
# translating: 31.52% --> enselvado,
# translating: 31.52% --> cepillado, bosky,
# translating: 31.52% --> brambly, braky,
# translating: 31.53% --> Bosque
# translating: 31.53% --> velo doble
# translating: 31.53% --> juncoso,
# translating: 31.54% --> desaliñado, escarpado,
# translating: 31.54% --> formando matorrales,
# translating: 31.54% --> entramado,
# translating: 31.55% --> sin arbolado, sin árboles,
# translating: 31.55% --> sin bosques
# translating: 31.56% --> no leñoso
# translating: 31.56% --> herbáceo
# translating: 31.56% --> blando, pulposo,
# translating: 31.57% --> material inconsciente;
# translating: 31.57% --> mundano, mercenario, materialista,
# translating: 31.57% --> terrestre, mundano,
# translating: 31.58% --> no mundano
# translating: 31.58% --> ermitaño, ermitaño, ermitaño, ermitaño, anacoreta,
# translating: 31.58% --> sobrenatural, espiritual,
# translating: 31.59% --> no mercenario
# translating: 31.59% --> Trenzada
# translating: 31.59% --> sin tejer
# translating: 31.60% --> tornillo sinfin
# translating: 31.60% --> atrito
# translating: 31.60% --> abollado
# translating: 31.61% --> aplaudido,
# translating: 31.61% --> Apesadumbrado, deteriorado, mordido por pulgas, abandonado, decrépito, chirriante,
# translating: 31.61% --> orejas de perro
# translating: 31.62% --> Raído
# translating: 31.62% --> sarnoso, sarnoso,
# translating: 31.62% --> polilla, apolillada,
# translating: 31.63% --> harapiento
# translating: 31.63% --> desgastado, raddled,
# translating: 31.63% --> cutre, cutre, andrajoso, apolillado,
# translating: 31.64% --> cutre, desaliñado,
# translating: 31.64% --> andrajoso, andrajoso,
# translating: 31.64% --> pulgar,
# translating: 31.65% --> gusanos, carcomidos, vermiculados,
# translating: 31.65% --> desgastado por la intemperie, curtido por la intemperie,
# translating: 31.65% --> bien gastado
# translating: 31.66% --> Nuevo
# translating: 31.66% --> sin meteorizar
# translating: 31.67% --> digno
# translating: 31.67% --> loable, loable, loable, loable,
# translating: 31.67% --> loable
# translating: 31.68% --> CUM LAUDE
# translating: 31.68% --> vale la pena merecer
# translating: 31.68% --> modelo, ejemplar,
# translating: 31.69% --> Magna cum Laude
# translating: 31.69% --> meritorio, meritorio,
# translating: 31.69% --> digno de mención, notable,
# translating: 31.70% --> citable,
# translating: 31.70% --> Sagradas
# translating: 31.70% --> Summa cum laude
# translating: 31.71% --> valorado, precioso,
# translating: 31.71% --> digno, valioso,
# translating: 31.71% --> que vale la pena
# translating: 31.72% --> indigno
# translating: 31.72% --> indigno, indigno,
# translating: 31.72% --> inmerecido
# translating: 31.73% --> sin mérito,
# translating: 31.73% --> xerico
# translating: 31.73% --> hídrico
# translating: 31.74% --> higrofítico,
# translating: 31.74% --> mésico
# translating: 31.74% --> mesofítico,
# translating: 31.75% --> Azonales
# translating: 31.75% --> azónico,
# translating: 31.75% --> sin telarañas
# translating: 31.76% --> reentrante, reentrante,
# translating: 31.76% --> Anticuerpos anti Rh negativos
# translating: 31.76% --> categoremático
# translating: 31.77% --> sincategoremático,
# translating: 31.77% --> Pro Vida
# translating: 31.78% --> no bautizado, no bautizado,
# translating: 31.78% --> benigno,
# translating: 31.78% --> malignos,
# translating: 31.79% --> no invertible,
# translating: 31.79% --> inmunocompetente
# translating: 31.79% --> Inmunodeficiencia
# translating: 31.80% --> de espuela larga
# translating: 31.80% --> legumbres de vaina mondadas
# translating: 31.80% --> de cubierta dura
# translating: 31.81% --> sin cáscara, sin cáscara,
# translating: 31.81% --> mandíbula cuadrada
# translating: 31.81% --> piel suave
# translating: 31.82% --> cernido
# translating: 31.82% --> sin flores, sin flores,
# translating: 31.82% --> portador de esporas,
# translating: 31.83% --> abático, abásico,
# translating: 31.83% --> abiente
# translating: 31.83% --> aclorhídrico
# translating: 31.84% --> acidótico
# translating: 31.84% --> Erupción acneiforme
# translating: 31.84% --> actinomicótico,
# translating: 31.85% --> aculeated, aculeate,
# translating: 31.85% --> adactylous,
# translating: 31.85% --> anteridial
# translating: 31.86% --> alexifármaco,
# translating: 31.86% --> Agentes Antivirales
# translating: 31.86% --> agonal,
# translating: 31.87% --> agranulocítico,
# translating: 31.87% --> alabastrina, alabastro,
# translating: 31.87% --> albinótico, albinista, albínico, albinal,
# translating: 31.88% --> algoide
# translating: 31.88% --> algolagnico,
# translating: 31.89% --> alcalótico
# translating: 31.89% --> Alantoides
# translating: 31.89% --> Alérgica
# translating: 31.90% --> alométrico
# translating: 31.90% --> alotropical, alotrópico,
# translating: 31.90% --> amalgamativo,
# translating: 31.91% --> amaurótico,
# translating: 31.91% --> ameboide, ameboide,
# translating: 31.91% --> de amatista,
# translating: 31.92% --> amniótico, amniótico, amnico,
# translating: 31.92% --> amorista
# translating: 31.92% --> amigdalina,
# translating: 31.93% --> anaclítico,
# translating: 31.93% --> anagógico, anagógico,
# translating: 31.93% --> Anarquismo
# translating: 31.94% --> anasarcous,
# translating: 31.94% --> anencefálico, anencefálico,
# translating: 31.94% --> anginoso, anginosa, anginoso,
# translating: 31.95% --> anglófilo
# translating: 31.95% --> anglofóbico
# translating: 31.95% --> serpentino,
# translating: 31.96% --> anictérico
# translating: 31.96% --> anisometrópico,
# translating: 31.96% --> anoxémico,
# translating: 31.97% --> anóxico
# translating: 31.97% --> Anserina
# translating: 31.97% --> antitumoral, antitumoral, antineoplásico, anticancerígeno,
# translating: 31.98% --> anúrico, anurético,
# translating: 31.98% --> ansiolítico
# translating: 31.98% --> Afaquia
# translating: 31.99% --> Afasia
# translating: 31.99% --> Apocalíptico
# translating: 32.00% --> apoplectoide, apoplectiforme,
# translating: 32.00% --> apotegmático, apotegmático,
# translating: 32.00% --> Apalaches
# translating: 32.01% --> arcaizante,
# translating: 32.01% --> arcángel, arcangélico,
# translating: 32.01% --> archiducal,
# translating: 32.02% --> archiepiscopal, archepiscopal,
# translating: 32.02% --> ascensional
# translating: 32.02% --> asteró,
# translating: 32.03% --> estolonífero,
# translating: 32.03% --> astomatal,
# translating: 32.03% --> programa registrado
# translating: 32.04% --> asinérgico
# translating: 32.04% --> atáxico, atáctico,
# translating: 32.04% --> Atonía
# translating: 32.05% --> auditivo
# translating: 32.05% --> autárquico, autárquico, autárquico,
# translating: 32.05% --> heterótrofo
# translating: 32.06% --> Avunculado
# translating: 32.06% --> Galardonado
# translating: 32.06% --> babuino
# translating: 32.07% --> baya, baccate,
# translating: 32.07% --> bacteriolítico,
# translating: 32.07% --> bacteriostático
# translating: 32.08% --> bacteroide, bacteroide, bacterioide, bacterioide,
# translating: 32.08% --> Ballet
# translating: 32.08% --> basidial
# translating: 32.09% --> basidiosporoso,
# translating: 32.09% --> bauxítico,
# translating: 32.09% --> conductista, conductista, conductista, conductista,
# translating: 32.10% --> benedictiva, benedictiva,
# translating: 32.10% --> afianzado
# translating: 32.11% --> benévolo
# translating: 32.11% --> bibliomaníaco,
# translating: 32.11% --> bicromatado
# translating: 32.12% --> Boratos
# translating: 32.12% --> braquioso
# translating: 32.12% --> bracteal
# translating: 32.13% --> bracted, bracteate,
# translating: 32.13% --> sin borde
# translating: 32.13% --> brobdingnagian,
# translating: 32.14% --> Bulimia
# translating: 32.14% --> como una rebaba
# translating: 32.14% --> butiráceo,
# translating: 32.15% --> butírico
# translating: 32.15% --> cacodemonic, cacodaemonic,
# translating: 32.15% --> mojones
# translating: 32.16% --> calcáreo, calcáreo,
# translating: 32.16% --> calcico
# translating: 32.16% --> calicó
# translating: 32.17% --> capsular
# translating: 32.17% --> carbocíclico
# translating: 32.17% --> carbolatado
# translating: 32.18% --> carcinógenas,
# translating: 32.18% --> carposporoso
# translating: 32.18% --> carúnculo, caruncular,
# translating: 32.19% --> catabólico, catabólico,
# translating: 32.19% --> catachrestical, catachrestic,
# translating: 32.19% --> catkinate
# translating: 32.20% --> chaffy, como paja,
# translating: 32.20% --> ferruginoso,
# translating: 32.20% --> benéficos
# translating: 32.21% --> quelato
# translating: 32.21% --> quelado, quelado,
# translating: 32.22% --> alegre
# translating: 32.22% --> Maternidad
# translating: 32.22% --> alegre
# translating: 32.23% --> Quitina
# translating: 32.23% --> Wilsonianismo
# translating: 32.23% --> cloze
# translating: 32.24% --> coccal
# translating: 32.24% --> Funciona con monedas
# translating: 32.24% --> Collar
# translating: 32.25% --> colegiado
# translating: 32.25% --> configuracional,
# translating: 32.25% --> Consonante
# translating: 32.26% --> constitucional
# translating: 32.26% --> inalámbrico/sin hilos
# translating: 32.26% --> cormos, cormose,
# translating: 32.27% --> Panícula
# translating: 32.27% --> Enlace covalente
# translating: 32.27% --> croupy
# translating: 32.28% --> crustáceo
# translating: 32.28% --> criogénico
# translating: 32.28% --> ctenoide, en forma de peine,
# translating: 32.29% --> como una natilla,
# translating: 32.29% --> cíclico
# translating: 32.29% --> a entregar en la Oficina Central RACE
# translating: 32.30% --> despótico, despótico,
# translating: 32.30% --> diagonalizable,
# translating: 32.30% --> sudorífico, diaforético,
# translating: 32.31% --> Charles Dickens
# translating: 32.31% --> modo
# translating: 32.31% --> numérico
# translating: 32.32% --> dimorfo, dimórfico,
# translating: 32.32% --> Omnidireccional
# translating: 32.33% --> direccional
# translating: 32.33% --> Ditirambo
# translating: 32.33% --> DUMPY
# translating: 32.34% --> disgénico, cacogénico,
# translating: 32.34% --> eugenésico
# translating: 32.34% --> ectópico (calificador)
# translating: 32.35% --> Fuerza electromotriz
# translating: 32.35% --> elegíaco,
# translating: 32.35% --> Elementales
# translating: 32.36% --> emulador,
# translating: 32.36% --> epilítico
# translating: 32.36% --> equinos
# translating: 32.37% --> eruptivo,
# translating: 32.37% --> eritematoso
# translating: 32.37% --> saliente,
# translating: 32.38% --> Existencialismo
# translating: 32.38% --> fermentable,
# translating: 32.38% --> febril, febril,
# translating: 32.39% --> fibrilosa
# translating: 32.39% --> fibrinoso
# translating: 32.39% --> No ficción
# translating: 32.40% --> Filaria
# translating: 32.40% --> escamoso, escamoso,
# translating: 32.40% --> de pedernal,
# translating: 32.41% --> florido
# translating: 32.41% --> foliado, foliado,
# translating: 32.41% --> forcipate,
# translating: 32.42% --> formalizado, formalista, formalizado,
# translating: 32.42% --> Formularios Farmacéuticos como Asunto
# translating: 32.42% --> cuatro manos
# translating: 32.43% --> preocupado
# translating: 32.43% --> desanimado
# translating: 32.44% --> Fricción
# translating: 32.44% --> olor a ajo
# translating: 32.44% --> gemífero,
# translating: 32.45% --> granulífero
# translating: 32.45% --> granulomatoso
# translating: 32.45% --> Myoxocephalus aenaeus
# translating: 32.46% --> camisa de pelo, camisa de pelo,
# translating: 32.46% --> no armónico
# translating: 32.46% --> como un brezo
# translating: 32.47% --> Espora
# translating: 32.47% --> Autorregulación
# translating: 32.47% --> Espora
# translating: 32.48% --> hircine,
# translating: 32.48% --> humanista, humanista,
# translating: 32.48% --> hidrocefálico
# translating: 32.49% --> hidrolizable,
# translating: 32.49% --> agnogénico
# translating: 32.49% --> Huésped Inmunocomprometido
# translating: 32.50% --> inmunodeprimido
# translating: 32.50% --> metric
# translating: 32.50% --> metric
# translating: 32.51% --> incestuoso
# translating: 32.51% --> inductivo
# translating: 32.51% --> Información
# translating: 32.52% --> no polar, no iónico,
# translating: 32.52% --> hecho un flan
# translating: 32.52% --> lactogénico
# translating: 32.53% --> jabonoso
# translating: 32.53% --> Leguminosas
# translating: 32.53% --> limacoide, limacina,
# translating: 32.54% --> sala de estar
# translating: 32.54% --> Loopy
# translating: 32.55% --> como un pulmón
# translating: 32.55% --> presocrático, presocrático,
# translating: 32.55% --> postdiluviano,
# translating: 32.56% --> omisivo
# translating: 32.56% --> miótico, miótico,
# translating: 32.56% --> ratonil, ratonil,
# translating: 32.57% --> mielinizado, medulado,
# translating: 32.57% --> amielínico,
# translating: 32.57% --> narcoléptico,
# translating: 32.58% --> neoteno, neoténico,
# translating: 32.58% --> tejido de orbes,
# translating: 32.58% --> - Empaquetable
# translating: 32.59% --> paranasal
# translating: 32.59% --> paroxístico
# translating: 32.59% --> no passerina,
# translating: 32.60% --> operaciones de mantenimiento
# translating: 32.60% --> turboso
# translating: 32.60% --> petaloide
# translating: 32.61% --> Fagocitosis
# translating: 32.61% --> no fotosintético,
# translating: 32.61% --> pictográfico,
# translating: 32.62% --> resistente a la penicilina,
# translating: 32.62% --> pleomórfico
# translating: 32.62% --> políticamente correcto
# translating: 32.63% --> Políticamente incorrecto
# translating: 32.63% --> pomposo, ceremonioso,
# translating: 32.63% --> posicionable,
# translating: 32.64% --> presintomático, preclínico,
# translating: 32.64% --> precanceroso
# translating: 32.64% --> Vasoconstricción
# translating: 32.65% --> prodrómico, prodrómico,
# translating: 32.65% --> propagativo,
# translating: 32.66% --> pútrido
# translating: 32.66% --> rabioso
# translating: 32.66% --> andrajoso,
# translating: 32.67% --> refractivo, refractario,
# translating: 32.67% --> parecido a la resina,
# translating: 32.67% --> viscosa, nerviosa,
# translating: 32.68% --> monogastrico
# translating: 32.68% --> ruritano
# translating: 32.68% --> escaleno
# translating: 32.69% --> Caspa
# translating: 32.69% --> autoinducido,
# translating: 32.69% --> Túbulos seminíferos
# translating: 32.70% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 21 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.70% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.70% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 20 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.71% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 19 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.71% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 19 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.71% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 19 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.72% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.72% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.72% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.73% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.73% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.73% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 17 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.74% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.74% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.74% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 16 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.75% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.75% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.75% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.76% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.76% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.77% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.77% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.77% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.78% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 12 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.78% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 12 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.78% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 11 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.79% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 11 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.79% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 11 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.79% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.80% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.80% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.80% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.81% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.81% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.81% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.82% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.82% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.82% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.83% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.83% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.83% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.84% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.84% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.84% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.85% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.85% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.85% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.86% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.86% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.86% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.87% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.87% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.88% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.88% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 01 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.88% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 01 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.89% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 59 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.90% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.91% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.92% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.93% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.94% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 53 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.95% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 53 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 53 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 52 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.96% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 52 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 52 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 51 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.97% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 51 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 51 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.98% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 50 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 50 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 49 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 32.99% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 49 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 49 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 48 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.00% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 48 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 48 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 47 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.01% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 47 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 47 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 46 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.02% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 46 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 45 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 45 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.03% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 45 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 44 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 44 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.04% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 44 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 43 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 43 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.05% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 42 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.06% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 42 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.06% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 42 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.06% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 41 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.07% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 41 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.07% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 41 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.07% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 40 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 40 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 40 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 39 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 38 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 38 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 33.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 58 MINUTES 37 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# ...
# translating: 45.08% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 15 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 14 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.09% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 13 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 11 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.10% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 10 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.11% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.11% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 09 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.11% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.12% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.12% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 08 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.12% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.13% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 07 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.13% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.13% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 06 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.14% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.14% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.15% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 05 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.15% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.15% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 04 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.16% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.16% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.16% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 03 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.17% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.17% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.17% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 02 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.18% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 01 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.18% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 01 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.18% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 01 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.19% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.19% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.19% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 34 MINUTES 00 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.20% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.20% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 59 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.20% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.21% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.21% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 58 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.21% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.22% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.22% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 57 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.22% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.23% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.23% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 56 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.23% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.24% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 55 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.24% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# translating: 45.24% --> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  08 HOURS 33 MINUTES 54 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6d842efdb927> in <module>
#       6
#       7 for idx in range(start_at,len(text_ls)):
# ----> 8     translation = translator.translate(text_ls.iloc[idx])
#       9     translated_ls.append(translation)
#      10     print('translating: {0:2.2f}% --> '.format(100 * idx/len(text_ls))+translation)
#
# ~\Anaconda3\lib\site-packages\translate\translate.py in translate(self, text)
#      40
#      41         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 42         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~\Anaconda3\lib\site-packages\translate\translate.py in <genexpr>(.0)
#      40
#      41         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 42         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# ~\Anaconda3\lib\site-packages\translate\providers\mymemory_translated.py in get_translation(self, text)
#      40
#      41     def get_translation(self, text):
# ---> 42         data = self._make_request(text)
#      43
#      44         translation = data['responseData']['translatedText']
#
# ~\Anaconda3\lib\site-packages\translate\providers\mymemory_translated.py in _make_request(self, text)
#      36             params['de'] = self.email
#      37
# ---> 38         response = requests.get(self.base_url, params=params, headers=self.headers)
#      39         return response.json()
#      40
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
total_ok = 530
translated_ls[0:total_ok]
# Out:
# ['bajo fuego, bajo ataque,',
#  'indefenso',
#  'Vulnerable',
#  'hermético, hermético al aire,',
#  'a prueba de bombas, a prueba de bombas,',
#  'defendible, defendible,',
#  'inatacable, inexpugnable, fuerte, seguro, inviolable, inexpugnable,',
#  'Apretado',
#  'Protegidas',
#  'oprimido',
#  'se busca',
#  'deseado, anhelado,',
#  'chaud',
#  'anhelado, deseado, anhelado,',
#  'buscado, buscado,',
#  'No deseado',
#  'abdicable',
#  'paria, sin casta,',
#  'fuera de lugar,',
#  'no reclamado',
#  'no buscado, no deseado,',
#  'no deseado, no deseado, no deseado,',
#  'cálido',
#  'tibio, tibio,',
#  'calentado',
#  'frío',
#  'programa de llamada',
#  'cálido',
#  'jarabe de fruta',
#  'Abundante',
#  'frío',
#  'sin respuesta',
#  'frío',
#  'Sangre fría',
#  'afectuoso',
#  'corazón frío,',
#  'curso frágil',
#  'lavable',
#  'lavado y uso, secado por goteo,',
#  'no lavable,',
#  'Encerado',
#  'sin cera',
#  'acelerador, acelerador,',
#  'acrecionario',
#  'acumulativo',
#  'maximizando, maximizando,',
#  'Con ajuste multiplicativo',
#  'maximización de beneficios, maximización de beneficios,',
#  'levantamiento',
#  'disminuyendo',
#  'depreciativo, depreciativo, depreciativo,',
#  'detractor,',
#  'disminuido',
#  'caídas',
#  'allargando,',
#  'inflacionario',
#  'Deflación',
#  'lactante',
#  'dispositivo de vestir',
#  'inservible',
#  'invadido por las malas hierbas',
#  'deshierbe',
#  'Bienvenido,',
#  'mal acogido',
#  'Uninvited',
#  'bueno,',
#  'asintomático, asintomático,',
#  'recuperado, curado, curado,',
#  'enfermo',
#  'herido, afligido,',
#  'angustia',
#  'malestar, mal tiempo, enfermizo, cutre, mal, puntiagudo, indispuesto, enfermo,',
#  'mareado, mareado, mareado, mareado,',
#  'Autismo Infantil',
#  'enfermo en cama, postrado en cama, postrado en cama, postrado en cama,',
#  'librea, hígado, bilioso,',
#  'bronquítico,',
#  'tísico',
#  'en recuperación, convaleciente,',
#  'alucinante, delirante,',
#  'diabético',
#  'mareado, vertiginoso, mareado, mareado,',
#  'Dispepsia',
#  'desmayo, aturdimiento, aturdimiento, ligero, débil,',
#  'febril, febril,',
#  'divertido',
#  'gotoso,',
#  'verde',
#  'Establecidas',
#  'enfermizo, enfermo, mareado, con náuseas, náuseas,',
#  'PARALISIS',
#  'paralizado, paralítico,',
#  'parapléjico',
#  'desvencijado, raquítico,',
#  'Escrófula',
#  'Mocoso',
#  'espástico',
#  'tuberculoso, tuberculoso,',
#  'sin curar',
#  'apretar permanentemente',
#  'húmedo, húmedo,',
#  'empapado, empapado,',
#  'húmedo',
#  'pegajoso, humeante, bochornoso,',
#  'enlodado',
#  'lluvioso, lluvioso,',
#  'pegajoso',
#  'Lavado',
#  'seco',
#  'Al sol, chamuscado, reseco, horneado, adust,',
#  'secado al aire',
#  'seco al aire',
#  'seco, árido,',
#  'completamente seco, completamente seco,',
#  'seco, desecado,',
#  'secadas;',
#  'sin lluvia,',
#  'semiseco',
#  'sediento',
#  'mojado, lactante,',
#  'seco',
#  'seco',
#  'sobre ruedas',
#  'sin ruedas',
#  'manual',
#  'sano',
#  'Nutritivo, nutritivo, nutritivo, nutritivo, alimentario, alimentario,',
#  '¿SALUDABLE PARA EL CORAZÓN?',
#  'saludable, saludable, bueno para ti,',
#  'sustancial, cuadrado, sólido, satisfactorio, abundante,',
#  'orgánico',
#  'salubre',
#  'malsano',
#  'insalubre, insalubre, insalubre,',
#  'mezquino, insustancial,',
#  'mórbido',
#  'vil, repugnante, mareado, ofensivo, repugnante, nauseabundo, nauseabundo, repugnante,',
#  'ancho, amplio,',
#  'radiante',
#  'de ala ancha,',
#  'como un abanico',
#  'estrecho',
#  'estrechamiento, constricción, constricción,',
#  'angosto',
#  'microhyla',
#  'delgado, delgado,',
#  'estrecho',
#  'afilado, afilado, estrechamiento,',
#  'ancho',
#  'es cómodo',
#  'estrecho',
#  'marginal, desnudo,',
#  'manejable,',
#  'inmanejable, inmanejable,',
#  'torpe, torpe, torpe, torpe,',
#  'engorroso, engorroso,',
#  'peluca',
#  'sin peluca',
#  'dispuesto (hallazgo)',
#  'Consentimiento',
#  'preparado, inclinado, dispuesto, dispuesto,',
#  'feliz, contento,',
#  'listo',
#  'estar dispuesto y ser capaz',
#  'reacio',
#  'reacio, loth, repugnante,',
#  'involuntario, involuntario,',
#  'en forma de ala, aliforme, alary, alar,',
#  'de alas delgadas',
#  'sin alas,',
#  'aptero, apteral,',
#  'no volador',
#  'sabio,',
#  'omnisciente, omnisciente,',
#  'sapiente, sagaz, perspicaz,',
#  'de búho,',
#  'sapiencial,',
#  'salvia',
#  'tonto',
#  'ridículo, ridículo, disparatado, ridículo, ridículo, idiota, irrisorio, loco, absurdo,',
#  'vacío, insensato, estúpido, fatuo, estúpido,',
#  'chiflado, chiflado, chiflado, tonto, cursi, tonto, chiflado, chiflado,',
#  'enamorado',
#  'loco, loco, descabellado,',
#  'equivocado, mal concebido,',
#  'espantoso, despistado, rattlepated, rattlebrained,',
#  'imprudente',
#  'enselvado,',
#  'cepillado, bosky,',
#  'brambly, braky,',
#  'Bosque',
#  'velo doble',
#  'juncoso,',
#  'desaliñado, escarpado,',
#  'formando matorrales,',
#  'entramado,',
#  'sin arbolado, sin árboles,',
#  'sin bosques',
#  'no leñoso',
#  'herbáceo',
#  'blando, pulposo,',
#  'material inconsciente;',
#  'mundano, mercenario, materialista,',
#  'terrestre, mundano,',
#  'no mundano',
#  'ermitaño, ermitaño, ermitaño, ermitaño, anacoreta,',
#  'sobrenatural, espiritual,',
#  'no mercenario',
#  'Trenzada',
#  'sin tejer',
#  'tornillo sinfin',
#  'atrito',
#  'abollado',
#  'aplaudido,',
#  'Apesadumbrado, deteriorado, mordido por pulgas, abandonado, decrépito, chirriante,',
#  'orejas de perro',
#  'Raído',
#  'sarnoso, sarnoso,',
#  'polilla, apolillada,',
#  'harapiento',
#  'desgastado, raddled,',
#  'cutre, cutre, andrajoso, apolillado,',
#  'cutre, desaliñado,',
#  'andrajoso, andrajoso,',
#  'pulgar,',
#  'gusanos, carcomidos, vermiculados,',
#  'desgastado por la intemperie, curtido por la intemperie,',
#  'bien gastado',
#  'Nuevo',
#  'sin meteorizar',
#  'digno',
#  'loable, loable, loable, loable,',
#  'loable',
#  'CUM LAUDE',
#  'vale la pena merecer',
#  'modelo, ejemplar,',
#  'Magna cum Laude',
#  'meritorio, meritorio,',
#  'digno de mención, notable,',
#  'citable,',
#  'Sagradas',
#  'Summa cum laude',
#  'valorado, precioso,',
#  'digno, valioso,',
#  'que vale la pena',
#  'indigno',
#  'indigno, indigno,',
#  'inmerecido',
#  'sin mérito,',
#  'xerico',
#  'hídrico',
#  'higrofítico,',
#  'mésico',
#  'mesofítico,',
#  'Azonales',
#  'azónico,',
#  'sin telarañas',
#  'reentrante, reentrante,',
#  'Anticuerpos anti Rh negativos',
#  'categoremático',
#  'sincategoremático,',
#  'Pro Vida',
#  'no bautizado, no bautizado,',
#  'benigno,',
#  'malignos,',
#  'no invertible,',
#  'inmunocompetente',
#  'Inmunodeficiencia',
#  'de espuela larga',
#  'legumbres de vaina mondadas',
#  'de cubierta dura',
#  'sin cáscara, sin cáscara,',
#  'mandíbula cuadrada',
#  'piel suave',
#  'cernido',
#  'sin flores, sin flores,',
#  'portador de esporas,',
#  'abático, abásico,',
#  'abiente',
#  'aclorhídrico',
#  'acidótico',
#  'Erupción acneiforme',
#  'actinomicótico,',
#  'aculeated, aculeate,',
#  'adactylous,',
#  'anteridial',
#  'alexifármaco,',
#  'Agentes Antivirales',
#  'agonal,',
#  'agranulocítico,',
#  'alabastrina, alabastro,',
#  'albinótico, albinista, albínico, albinal,',
#  'algoide',
#  'algolagnico,',
#  'alcalótico',
#  'Alantoides',
#  'Alérgica',
#  'alométrico',
#  'alotropical, alotrópico,',
#  'amalgamativo,',
#  'amaurótico,',
#  'ameboide, ameboide,',
#  'de amatista,',
#  'amniótico, amniótico, amnico,',
#  'amorista',
#  'amigdalina,',
#  'anaclítico,',
#  'anagógico, anagógico,',
#  'Anarquismo',
#  'anasarcous,',
#  'anencefálico, anencefálico,',
#  'anginoso, anginosa, anginoso,',
#  'anglófilo',
#  'anglofóbico',
#  'serpentino,',
#  'anictérico',
#  'anisometrópico,',
#  'anoxémico,',
#  'anóxico',
#  'Anserina',
#  'antitumoral, antitumoral, antineoplásico, anticancerígeno,',
#  'anúrico, anurético,',
#  'ansiolítico',
#  'Afaquia',
#  'Afasia',
#  'Apocalíptico',
#  'apoplectoide, apoplectiforme,',
#  'apotegmático, apotegmático,',
#  'Apalaches',
#  'arcaizante,',
#  'arcángel, arcangélico,',
#  'archiducal,',
#  'archiepiscopal, archepiscopal,',
#  'ascensional',
#  'asteró,',
#  'estolonífero,',
#  'astomatal,',
#  'programa registrado',
#  'asinérgico',
#  'atáxico, atáctico,',
#  'Atonía',
#  'auditivo',
#  'autárquico, autárquico, autárquico,',
#  'heterótrofo',
#  'Avunculado',
#  'Galardonado',
#  'babuino',
#  'baya, baccate,',
#  'bacteriolítico,',
#  'bacteriostático',
#  'bacteroide, bacteroide, bacterioide, bacterioide,',
#  'Ballet',
#  'basidial',
#  'basidiosporoso,',
#  'bauxítico,',
#  'conductista, conductista, conductista, conductista,',
#  'benedictiva, benedictiva,',
#  'afianzado',
#  'benévolo',
#  'bibliomaníaco,',
#  'bicromatado',
#  'Boratos',
#  'braquioso',
#  'bracteal',
#  'bracted, bracteate,',
#  'sin borde',
#  'brobdingnagian,',
#  'Bulimia',
#  'como una rebaba',
#  'butiráceo,',
#  'butírico',
#  'cacodemonic, cacodaemonic,',
#  'mojones',
#  'calcáreo, calcáreo,',
#  'calcico',
#  'calicó',
#  'capsular',
#  'carbocíclico',
#  'carbolatado',
#  'carcinógenas,',
#  'carposporoso',
#  'carúnculo, caruncular,',
#  'catabólico, catabólico,',
#  'catachrestical, catachrestic,',
#  'catkinate',
#  'chaffy, como paja,',
#  'ferruginoso,',
#  'benéficos',
#  'quelato',
#  'quelado, quelado,',
#  'alegre',
#  'Maternidad',
#  'alegre',
#  'Quitina',
#  'Wilsonianismo',
#  'cloze',
#  'coccal',
#  'Funciona con monedas',
#  'Collar',
#  'colegiado',
#  'configuracional,',
#  'Consonante',
#  'constitucional',
#  'inalámbrico/sin hilos',
#  'cormos, cormose,',
#  'Panícula',
#  'Enlace covalente',
#  'croupy',
#  'crustáceo',
#  'criogénico',
#  'ctenoide, en forma de peine,',
#  'como una natilla,',
#  'cíclico',
#  'a entregar en la Oficina Central RACE',
#  'despótico, despótico,',
#  'diagonalizable,',
#  'sudorífico, diaforético,',
#  'Charles Dickens',
#  'modo',
#  'numérico',
#  'dimorfo, dimórfico,',
#  'Omnidireccional',
#  'direccional',
#  'Ditirambo',
#  'DUMPY',
#  'disgénico, cacogénico,',
#  'eugenésico',
#  'ectópico (calificador)',
#  'Fuerza electromotriz',
#  'elegíaco,',
#  'Elementales',
#  'emulador,',
#  'epilítico',
#  'equinos',
#  'eruptivo,',
#  'eritematoso',
#  'saliente,',
#  'Existencialismo',
#  'fermentable,',
#  'febril, febril,',
#  'fibrilosa',
#  'fibrinoso',
#  'No ficción',
#  'Filaria',
#  'escamoso, escamoso,',
#  'de pedernal,',
#  'florido',
#  'foliado, foliado,',
#  'forcipate,',
#  'formalizado, formalista, formalizado,',
#  'Formularios Farmacéuticos como Asunto',
#  'cuatro manos',
#  'preocupado',
#  'desanimado',
#  'Fricción',
#  'olor a ajo',
#  'gemífero,',
#  'granulífero',
#  'granulomatoso',
#  'Myoxocephalus aenaeus',
#  'camisa de pelo, camisa de pelo,',
#  'no armónico',
#  'como un brezo',
#  'Espora',
#  'Autorregulación',
#  'Espora',
#  'hircine,',
#  'humanista, humanista,',
#  'hidrocefálico',
#  'hidrolizable,',
#  'agnogénico',
#  'Huésped Inmunocomprometido',
#  'inmunodeprimido',
#  'metric',
#  'metric',
#  'incestuoso',
#  'inductivo',
#  'Información',
#  'no polar, no iónico,',
#  'hecho un flan',
#  'lactogénico',
#  'jabonoso',
#  'Leguminosas',
#  'limacoide, limacina,',
#  'sala de estar',
#  'Loopy',
#  'como un pulmón',
#  'presocrático, presocrático,',
#  'postdiluviano,',
#  'omisivo',
#  'miótico, miótico,',
#  'ratonil, ratonil,',
#  'mielinizado, medulado,',
#  'amielínico,',
#  'narcoléptico,',
#  'neoteno, neoténico,',
#  'tejido de orbes,',
#  '- Empaquetable',
#  'paranasal',
#  'paroxístico',
#  'no passerina,',
#  'operaciones de mantenimiento',
#  'turboso',
#  'petaloide',
#  'Fagocitosis',
#  'no fotosintético,',
#  'pictográfico,',
#  'resistente a la penicilina,',
#  'pleomórfico',
#  'políticamente correcto',
#  'Políticamente incorrecto',
#  'pomposo, ceremonioso,',
#  'posicionable,',
#  'presintomático, preclínico,',
#  'precanceroso',
#  'Vasoconstricción',
#  'prodrómico, prodrómico,',
#  'propagativo,',
#  'pútrido',
#  'rabioso',
#  'andrajoso,',
#  'refractivo, refractario,',
#  'parecido a la resina,',
#  'viscosa, nerviosa,',
#  'monogastrico',
#  'ruritano',
#  'escaleno',
#  'Caspa',
#  'autoinducido,',
#  'Túbulos seminíferos']

# %%
translated_ls = translated_ls[0:total_ok]
row_list = range(start_at, (start_at + total_ok))

df = pd.DataFrame(data=translated_ls, index=row_list)
df
# Out:
#                                             0
# 8983                 bajo fuego, bajo ataque,
# 8984                                indefenso
# 8985                               Vulnerable
# 8986            hermético, hermético al aire,
# 8987  a prueba de bombas, a prueba de bombas,
# ...                                       ...
# 9508                                 ruritano
# 9509                                 escaleno
# 9510                                    Caspa
# 9511                            autoinducido,
# 9512                      Túbulos seminíferos
#
# [530 rows x 1 columns]

# %%
save_file = 'words_to_translate_2'
save_path = os.path.join(save_file + '.csv')
df.to_csv(save_path)
