# %% [markdown]
# **Facebook CSV concatenate**

# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %%
# Import CSVs
epk_posts = pd.read_csv("./epk_fb_posts.csv")
epk_reactions = pd.read_csv("./epk_fb_reactions.csv")
offcorss_posts = pd.read_csv("./offcorss_fb_posts.csv")
offcorss_reactions = pd.read_csv("./offcorss_fb_reactions.csv")
polito_posts = pd.read_csv("./PolitoColombia_fb_posts.csv")
polito_reactions = pd.read_csv("./PolitoColombia_fb_reactions.csv")

# %%
#Merging Posts and Reactions
offcorss = offcorss_posts.merge(offcorss_reactions, on='post_id')
offcorss.loc[:, 'brand_username'] = 'offcorss'
epk = epk_posts.merge(epk_reactions, on='post_id')
epk.loc[:, 'brand_username'] = 'epk'
polito = polito_posts.merge(polito_reactions, on='post_id')
polito.loc[:, 'brand_username'] = 'polito'

# %%
#Integrate Facebook DF
facebook = offcorss.append(epk)
facebook = facebook.append(polito)

# %%
#Lengh check
print(len(epk))
print(len(polito))
print(len(offcorss))
print(len(facebook))
# Out:
# 1998
# 1998
# 1834
# 5830

# %%
#Replace NaN for Zero in last columns
facebook['Me gusta'].fillna(0, inplace=True)
facebook['Me encanta'].fillna(0, inplace=True)
facebook['Me enfada'].fillna(0, inplace=True)
facebook['Me importa'].fillna(0, inplace=True)
facebook['Me asombra'].fillna(0, inplace=True)
facebook['Me divierte'].fillna(0, inplace=True)
facebook['Me entristece'].fillna(0, inplace=True)
facebook['likes'].fillna(0, inplace=True)

# %%
facebook
# Out:
#            post_id                                               text  \
# 0     3.326919e+15  ¡¡Gomitaaaas!! ¿Qué mejor manera de sorprender...
# 1     3.326913e+15  ¿Qué experimento has hecho en este tiempo en c...
# 2     3.326892e+15  ¡Espeluznante! Máscaras con gráficos especiale...
# 3     3.326842e+15  Ahora, no solo tenemos productos para niños, s...
# 4     3.326872e+15  ¡Diseños únicos que completan los días más div...
# ...            ...                                                ...
# 1993  1.494958e+15  ¡Te estamos esperando para que hagas parte del...
# 1994  1.494957e+15  ¡Dile NO al maltrato infantil! Los derechos de...
# 1995  1.493730e+15  ¡Suaves y divertidas! Nuestras medias siempre ...
# 1996  1.489553e+15  ¡Tomi no encuentra a sus amigos! :( Ayúdalos a...
# 1997  1.489552e+15  ¡Celebremos juntos el Día del Idioma! Comparte...
#
#                                               post_text shared_text  \
# 0     ¡¡Gomitaaaas!! ¿Qué mejor manera de sorprender...         NaN
# 1     ¿Qué experimento has hecho en este tiempo en c...         NaN
# 2     ¡Espeluznante! Máscaras con gráficos especiale...         NaN
# 3     Ahora, no solo tenemos productos para niños, s...         NaN
# 4     ¡Diseños únicos que completan los días más div...         NaN
# ...                                                 ...         ...
# 1993  ¡Te estamos esperando para que hagas parte del...         NaN
# 1994  ¡Dile NO al maltrato infantil! Los derechos de...         NaN
# 1995  ¡Suaves y divertidas! Nuestras medias siempre ...         NaN
# 1996  ¡Tomi no encuentra a sus amigos! :( Ayúdalos a...         NaN
# 1997  ¡Celebremos juntos el Día del Idioma! Comparte...         NaN
#
#                      time                                              image  \
# 0     2020-09-30 13:30:01  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# 1     2020-09-30 09:00:03                                                NaN
# 2     2020-09-29 20:00:01  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# 3     2020-09-29 15:00:02  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# 4     2020-09-29 12:30:01  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# ...                   ...                                                ...
# 1993  2017-04-25 16:55:08  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# 1994  2017-04-25 14:58:31  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# 1995  2017-04-24 18:00:00  https://scontent.feoh1-1.fna.fbcdn.net/v/t31.0...
# 1996  2017-04-23 15:35:00  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
# 1997  2017-04-23 11:35:00  https://scontent.feoh1-1.fna.fbcdn.net/v/t1.0-...
#
#                                                   video  video_thumbnail  \
# 0                                                   NaN              NaN
# 1     https://video.feoh1-1.fna.fbcdn.net/v/t42.9040...              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 1993                                                NaN              NaN
# 1994                                                NaN              NaN
# 1995                                                NaN              NaN
# 1996                                                NaN              NaN
# 1997                                                NaN              NaN
#
#           video_id  likes  ...                               link  \
# 0              NaN     22  ...             https://bit.ly/3hLlyMA
# 1     3.893379e+14     15  ...        https://bit.ly/ocblogseptOC
# 2              NaN     65  ...  https://bit.ly/disfracesninoss-Oc
# 3              NaN     95  ...         https://bit.ly/alianzas-c9
# 4              NaN    193  ...      https://bit.ly/tenisninasepOC
# ...            ...    ...  ...                                ...
# 1993           NaN    218  ...                                NaN
# 1994           NaN     87  ...                                NaN
# 1995           NaN     59  ...                                NaN
# 1996           NaN     17  ...                                NaN
# 1997           NaN     26  ...                                NaN
#
#            user_id Me gusta Me encanta  Me enfada Me importa Me asombra  \
# 0     1.408078e+14       25          1          0        0.0        0.0
# 1     1.408078e+14       15          1          0        0.0        0.0
# 2     1.408078e+14       65          8          0        0.0        0.0
# 3     1.408078e+14       95          8          0        0.0        0.0
# 4     1.408078e+14      194         25          0        1.0        0.0
# ...            ...      ...        ...        ...        ...        ...
# 1993  1.213982e+14        0          0          0        0.0        0.0
# 1994  1.213982e+14        0          0          0        0.0        0.0
# 1995  1.213982e+14        0          0          0        0.0        0.0
# 1996  1.213982e+14        0          0          0        0.0        0.0
# 1997  1.213982e+14        0          0          0        0.0        0.0
#
#      Me divierte  Me entristece  brand_username
# 0            0.0            0.0        offcorss
# 1            0.0            0.0        offcorss
# 2            1.0            0.0        offcorss
# 3            0.0            0.0        offcorss
# 4            0.0            0.0        offcorss
# ...          ...            ...             ...
# 1993         0.0            0.0          polito
# 1994         0.0            0.0          polito
# 1995         0.0            0.0          polito
# 1996         0.0            0.0          polito
# 1997         0.0            0.0          polito
#
# [5830 rows x 23 columns]

# %%
#Export CSV
facebook.to_csv('facebook.csv', index = True)
