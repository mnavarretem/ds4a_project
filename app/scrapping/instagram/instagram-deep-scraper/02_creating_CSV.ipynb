# %% [markdown]
# # Instagram Deep Scraping Cleaning
# We have use the library `instaloader` to scrap the instagram posts and comments since 2019 for Offcorss, EPK and Politokids profiles. Each post is stored in a separated `.json` file, and the ones that have any comment also have a separated file for the list of comments.
#
# In this notebook we are going to read all those files for each company and get them into a new file that follows the schema of the database that we have created.

# %%
import pandas as pd
import numpy as np
import json
import os
import glob
import preprocessor as p
from datetime import datetime

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## Reading all files in a Pandas DF
#
# First, we are going to iter in the folders of the profiles names. For each file we are going to open it in a dataframe, and store it in a list deppending if it is a post or a comment. At the end, we are going to append all the openned dataframes to a `ig_posts` and `ig_comments` dataframes.

# %%
company_names = ['offcorss', 'epk', 'politokids']

company_posts_df = []
company_comments_df = []

for company in company_names:
    files_list = glob.glob(f'{company}/*.json')
    post_list = [file for file in files_list if not 'comments' in file]
    
    df_posts_list = []
    for post in post_list:
        temp_post_df = pd.read_json(post).drop(columns='instaloader')
        df_posts_list.append(pd.read_json(post).drop(columns='instaloader'))
        comment = post.replace('.json', '_comments.json')
        if comment in files_list:
            temp_comment_df = pd.read_json(comment)
            temp_comment_df['post_id'] = temp_post_df.loc['id','node']
            temp_comment_df['post_shortcode'] = temp_post_df.loc['shortcode','node']
            temp_comment_df['brand'] = company
            company_comments_df.append(temp_comment_df)
    
    company_posts = pd.concat(df_posts_list, axis=1).transpose()
    df_info = ['id', 'shortcode', 'edge_media_to_caption', 'taken_at_timestamp', '__typename', 'is_ad', 'is_video', 'edge_media_preview_like', 'edge_media_to_comment']
    company_posts = company_posts[df_info]
    company_posts['posts_company'] = company
    company_posts_df.append(company_posts)
    
ig_posts = pd.concat(company_posts_df)
ig_comments = pd.concat(company_comments_df)

# %%
copyp = ig_posts.copy()
copyc = ig_comments.copy()

# %%
ig_posts.head()
# Out:
#                        id    shortcode  \
# node  1946502669929734835  BsDXd2DguKz
# node  1946624133611601575  BsDzFX7Hz6n
# node  1946744414957729955  BsEObsqB_ij
# node  1947257691818809835  BsGDI2_Adnr
# node  1947346707928591260  BsGXYNsnCuc
#
#                                   edge_media_to_caption taken_at_timestamp  \
# node  {'edges': [{'node': {'text': '¡FELIZ AÑO NUEVO...         1546261222
# node  {'edges': [{'node': {'text': '¡Hoy es un día p...         1546275701
# node  {'edges': [{'node': {'text': '¡Estamos listos ...         1546290040
# node  {'edges': [{'node': {'text': 'Día 1 del año 🎉⭐...         1546351227
# node  {'edges': [{'node': {'text': 'UN NUEVO AÑO com...         1546361839
#
#         __typename  is_ad is_video      edge_media_preview_like  \
# node    GraphImage    NaN    False               {'count': 308}
# node  GraphSidecar    NaN    False               {'count': 212}
# node    GraphImage    NaN    False               {'count': 278}
# node    GraphImage  False    False  {'count': 126, 'edges': []}
# node  GraphSidecar    NaN    False               {'count': 391}
#
#                                   edge_media_to_comment posts_company
# node                                       {'count': 0}      offcorss
# node                                       {'count': 0}      offcorss
# node                                       {'count': 0}      offcorss
# node  {'count': 1, 'edges': [], 'page_info': {'end_c...      offcorss
# node                                       {'count': 0}      offcorss

# %%
ig_comments.head()
# Out:
#              id          created_at  \
# 0  1.794235e+16 2019-01-01 16:42:54
# 0  1.801764e+16 2019-01-02 16:45:57
# 0  1.791861e+16 2019-01-02 18:48:08
# 0  1.798609e+16 2019-01-03 03:33:23
# 1  1.790035e+16 2019-01-03 01:00:38
#
#                                                 text  \
# 0  Así es un día para disfrutar  sana mente y con...
# 0                     Buenos días que precio tienen?
# 0                                                  🎊
# 0                                  Hermosa mi sheshe
# 1   Cuanto cuesta el vestido de manga larga talla 14
#
#                                                owner  likes_count  \
# 0  {'id': '8679040928', 'is_verified': False, 'pr...          1.0
# 0  {'id': '2252949863', 'is_verified': False, 'pr...          1.0
# 0  {'id': '9918008061', 'is_verified': False, 'pr...          1.0
# 0  {'id': '4903013997', 'is_verified': False, 'pr...          1.0
# 1  {'id': '2158477951', 'is_verified': False, 'pr...          3.0
#
#                                              answers              post_id  \
# 0                                                 []  1947257691818809835
# 0  [{'id': 17953738438218094, 'created_at': 15464...  1947952244502703605
# 0                                                 []  1948073194162672935
# 0                                                 []  1948284380053077836
# 1  [{'id': 18020433541055266, 'created_at': 15464...  1948284380053077836
#
#   post_shortcode     brand
# 0    BsGDI2_Adnr  offcorss
# 0    BsIhD7lAi31  offcorss
# 0    BsI8j-uhtUn  offcorss
# 0    BsJslI6gX9M  offcorss
# 1    BsJslI6gX9M  offcorss

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Cleaning the posts DF
# First, we are going to change so that they correspond to the same names of the database design.

# %%
ig_posts.reset_index(drop=True, inplace=True)

ig_posts.rename(columns={
    'id':'post_id',
    'edge_media_to_caption':'text',
    'taken_at_timestamp':'time',
    '__typename':'type',
    'edge_media_preview_like':'total_responses',
    'edge_media_to_comment':'total_comments',
    'posts_company':'brand_username'
}, inplace=True)

ig_posts.head()
# Out:
#                post_id    shortcode  \
# 0  1946502669929734835  BsDXd2DguKz
# 1  1946624133611601575  BsDzFX7Hz6n
# 2  1946744414957729955  BsEObsqB_ij
# 3  1947257691818809835  BsGDI2_Adnr
# 4  1947346707928591260  BsGXYNsnCuc
#
#                                                 text        time  \
# 0  {'edges': [{'node': {'text': '¡FELIZ AÑO NUEVO...  1546261222
# 1  {'edges': [{'node': {'text': '¡Hoy es un día p...  1546275701
# 2  {'edges': [{'node': {'text': '¡Estamos listos ...  1546290040
# 3  {'edges': [{'node': {'text': 'Día 1 del año 🎉⭐...  1546351227
# 4  {'edges': [{'node': {'text': 'UN NUEVO AÑO com...  1546361839
#
#            type  is_ad is_video              total_responses  \
# 0    GraphImage    NaN    False               {'count': 308}
# 1  GraphSidecar    NaN    False               {'count': 212}
# 2    GraphImage    NaN    False               {'count': 278}
# 3    GraphImage  False    False  {'count': 126, 'edges': []}
# 4  GraphSidecar    NaN    False               {'count': 391}
#
#                                       total_comments brand_username
# 0                                       {'count': 0}       offcorss
# 1                                       {'count': 0}       offcorss
# 2                                       {'count': 0}       offcorss
# 3  {'count': 1, 'edges': [], 'page_info': {'end_c...       offcorss
# 4                                       {'count': 0}       offcorss

# %% [markdown]
# Now, we see that the columns `text`, `total_responses` and `total_comments` have a dictionary in them, but we are only interested in one field. Then, we are going to extract that value of those columns.

# %%
ig_posts['text'] = ig_posts.text.apply(lambda x: x['edges'][0]['node']['text'] if x['edges'] != [] else "")
ig_posts['total_responses'] = ig_posts.total_responses.apply(lambda x: x['count'])
ig_posts['total_comments'] = ig_posts.total_comments.apply(lambda x: x['count'])

ig_posts.head()
# Out:
#                post_id    shortcode  \
# 0  1946502669929734835  BsDXd2DguKz
# 1  1946624133611601575  BsDzFX7Hz6n
# 2  1946744414957729955  BsEObsqB_ij
# 3  1947257691818809835  BsGDI2_Adnr
# 4  1947346707928591260  BsGXYNsnCuc
#
#                                                 text        time  \
# 0  ¡FELIZ AÑO NUEVO para todos! 😎✨❤ Les deseamos ...  1546261222
# 1  ¡Hoy es un día para AGRADECER por cada uno de ...  1546275701
# 2  ¡Estamos listos para celebrar y recibir el 201...  1546290040
# 3  Día 1 del año 🎉⭐🌈 Un día para disfrutar en fam...  1546351227
# 4  UN NUEVO AÑO comienza, y viene lleno de nuevos...  1546361839
#
#            type  is_ad is_video  total_responses  total_comments  \
# 0    GraphImage    NaN    False              308               0
# 1  GraphSidecar    NaN    False              212               0
# 2    GraphImage    NaN    False              278               0
# 3    GraphImage  False    False              126               1
# 4  GraphSidecar    NaN    False              391               0
#
#   brand_username
# 0       offcorss
# 1       offcorss
# 2       offcorss
# 3       offcorss
# 4       offcorss

# %% [markdown]
# It should be interesting for the analysis to have the associed URL to the post. After exploring the instagram interface we have seen that all the post have the same URL (https://www.instagram.com/p/.../) where the `...` is an unique identificator of each post. Then, we have realized that the code used is the same in the `shortcode` column, so we created the `post_url` column with that information.
#
# Also, we converted the `time` column to date format, and we extracted the hashtags from the `text` column.

# %%
ig_posts["time"] = ig_posts.time.apply(datetime.fromtimestamp)
ig_posts["post_url"] = ig_posts.shortcode.apply(lambda x: f'https://www.instagram.com/p/{x}/')
ig_posts["hashtags"] = ig_posts.text.apply(lambda t: [h.match for h in p.parse(t).hashtags] if p.parse(t).hashtags else None)

ig_posts.head()
# Out:
#                post_id    shortcode  \
# 0  1946502669929734835  BsDXd2DguKz
# 1  1946624133611601575  BsDzFX7Hz6n
# 2  1946744414957729955  BsEObsqB_ij
# 3  1947257691818809835  BsGDI2_Adnr
# 4  1947346707928591260  BsGXYNsnCuc
#
#                                                 text                time  \
# 0  ¡FELIZ AÑO NUEVO para todos! 😎✨❤ Les deseamos ... 2018-12-31 13:00:22
# 1  ¡Hoy es un día para AGRADECER por cada uno de ... 2018-12-31 17:01:41
# 2  ¡Estamos listos para celebrar y recibir el 201... 2018-12-31 21:00:40
# 3  Día 1 del año 🎉⭐🌈 Un día para disfrutar en fam... 2019-01-01 14:00:27
# 4  UN NUEVO AÑO comienza, y viene lleno de nuevos... 2019-01-01 16:57:19
#
#            type  is_ad is_video  total_responses  total_comments  \
# 0    GraphImage    NaN    False              308               0
# 1  GraphSidecar    NaN    False              212               0
# 2    GraphImage    NaN    False              278               0
# 3    GraphImage  False    False              126               1
# 4  GraphSidecar    NaN    False              391               0
#
#   brand_username                                  post_url  \
# 0       offcorss  https://www.instagram.com/p/BsDXd2DguKz/
# 1       offcorss  https://www.instagram.com/p/BsDzFX7Hz6n/
# 2       offcorss  https://www.instagram.com/p/BsEObsqB_ij/
# 3       offcorss  https://www.instagram.com/p/BsGDI2_Adnr/
# 4       offcorss  https://www.instagram.com/p/BsGXYNsnCuc/
#
#                          hashtags
# 0  [#HappyNewYear2019, #OFFCORSS]
# 1      [#HappyNewYear, #OFFCORSS]
# 2  [#HappyNewYear2019, #OFFCORSS]
# 3     [#FelizAñoNuevo, #OFFCORSS]
# 4     [#FelizAñoNuevo, #OFFCORSS]

# %% [markdown]
# ---------------------------

# %% [markdown]
# ## Cleaning the comments DF

# %%
ig_comments.head()
# Out:
#              id          created_at  \
# 0  1.794235e+16 2019-01-01 16:42:54
# 0  1.801764e+16 2019-01-02 16:45:57
# 0  1.791861e+16 2019-01-02 18:48:08
# 0  1.798609e+16 2019-01-03 03:33:23
# 1  1.790035e+16 2019-01-03 01:00:38
#
#                                                 text  \
# 0  Así es un día para disfrutar  sana mente y con...
# 0                     Buenos días que precio tienen?
# 0                                                  🎊
# 0                                  Hermosa mi sheshe
# 1   Cuanto cuesta el vestido de manga larga talla 14
#
#                                                owner  likes_count  \
# 0  {'id': '8679040928', 'is_verified': False, 'pr...          1.0
# 0  {'id': '2252949863', 'is_verified': False, 'pr...          1.0
# 0  {'id': '9918008061', 'is_verified': False, 'pr...          1.0
# 0  {'id': '4903013997', 'is_verified': False, 'pr...          1.0
# 1  {'id': '2158477951', 'is_verified': False, 'pr...          3.0
#
#                                              answers              post_id  \
# 0                                                 []  1947257691818809835
# 0  [{'id': 17953738438218094, 'created_at': 15464...  1947952244502703605
# 0                                                 []  1948073194162672935
# 0                                                 []  1948284380053077836
# 1  [{'id': 18020433541055266, 'created_at': 15464...  1948284380053077836
#
#   post_shortcode     brand
# 0    BsGDI2_Adnr  offcorss
# 0    BsIhD7lAi31  offcorss
# 0    BsI8j-uhtUn  offcorss
# 0    BsJslI6gX9M  offcorss
# 1    BsJslI6gX9M  offcorss

# %%
ig_comments.reset_index(drop=True, inplace=True)

ig_comments.rename(columns={
    "id":"response_id",
    "brand":"brand_username",
    "post_id":"rootPost_id",
    "owner":"username",
    "created_at":"time",
    "likes_count":"likes"
}, inplace=True)

ig_comments.head()
# Out:
#     response_id                time  \
# 0  1.794235e+16 2019-01-01 16:42:54
# 1  1.801764e+16 2019-01-02 16:45:57
# 2  1.791861e+16 2019-01-02 18:48:08
# 3  1.798609e+16 2019-01-03 03:33:23
# 4  1.790035e+16 2019-01-03 01:00:38
#
#                                                 text  \
# 0  Así es un día para disfrutar  sana mente y con...
# 1                     Buenos días que precio tienen?
# 2                                                  🎊
# 3                                  Hermosa mi sheshe
# 4   Cuanto cuesta el vestido de manga larga talla 14
#
#                                             username  likes  \
# 0  {'id': '8679040928', 'is_verified': False, 'pr...    1.0
# 1  {'id': '2252949863', 'is_verified': False, 'pr...    1.0
# 2  {'id': '9918008061', 'is_verified': False, 'pr...    1.0
# 3  {'id': '4903013997', 'is_verified': False, 'pr...    1.0
# 4  {'id': '2158477951', 'is_verified': False, 'pr...    3.0
#
#                                              answers          rootPost_id  \
# 0                                                 []  1947257691818809835
# 1  [{'id': 17953738438218094, 'created_at': 15464...  1947952244502703605
# 2                                                 []  1948073194162672935
# 3                                                 []  1948284380053077836
# 4  [{'id': 18020433541055266, 'created_at': 15464...  1948284380053077836
#
#   post_shortcode brand_username
# 0    BsGDI2_Adnr       offcorss
# 1    BsIhD7lAi31       offcorss
# 2    BsI8j-uhtUn       offcorss
# 3    BsJslI6gX9M       offcorss
# 4    BsJslI6gX9M       offcorss

# %% [markdown]
# From this dataframe there isn´t too much to do. We are going to take only the `ùsername` for each dictionary of that column, and we are going to convert the `likes` column to int type.

# %%
ig_comments["likes"] = ig_comments.likes.astype('int')
ig_comments["username"] = ig_comments.username.apply(lambda x: x['username'])

ig_comments.head()
# Out:
#     response_id                time  \
# 0  1.794235e+16 2019-01-01 16:42:54
# 1  1.801764e+16 2019-01-02 16:45:57
# 2  1.791861e+16 2019-01-02 18:48:08
# 3  1.798609e+16 2019-01-03 03:33:23
# 4  1.790035e+16 2019-01-03 01:00:38
#
#                                                 text          username  likes  \
# 0  Así es un día para disfrutar  sana mente y con...    rosaliafaneite      1
# 1                     Buenos días que precio tienen?  aleja.vasquez911      1
# 2                                                  🎊        pactrii188      1
# 3                                  Hermosa mi sheshe   dalekeyboutique      1
# 4   Cuanto cuesta el vestido de manga larga talla 14       delgadoa953      3
#
#                                              answers          rootPost_id  \
# 0                                                 []  1947257691818809835
# 1  [{'id': 17953738438218094, 'created_at': 15464...  1947952244502703605
# 2                                                 []  1948073194162672935
# 3                                                 []  1948284380053077836
# 4  [{'id': 18020433541055266, 'created_at': 15464...  1948284380053077836
#
#   post_shortcode brand_username
# 0    BsGDI2_Adnr       offcorss
# 1    BsIhD7lAi31       offcorss
# 2    BsI8j-uhtUn       offcorss
# 3    BsJslI6gX9M       offcorss
# 4    BsJslI6gX9M       offcorss

# %% [markdown]
# As we can see, there are all the comments for all the scraped posts, but there is a column named `answers` that conteins all the answers to that comment. From that column we are going to take the same fields that a normal comment.

# %%
ig_answers = ig_comments[ig_comments.answers.apply(len) != 0][['rootPost_id', 'response_id', 'answers', 'brand_username']].reset_index(drop=True)

ig_answers.head()
# Out:
#            rootPost_id   response_id  \
# 0  1947952244502703605  1.801764e+16
# 1  1948284380053077836  1.790035e+16
# 2  1948805488864773596  1.796902e+16
# 3  1948805488864773596  1.799455e+16
# 4  1948805488864773596  1.788860e+16
#
#                                              answers brand_username
# 0  [{'id': 17953738438218094, 'created_at': 15464...       offcorss
# 1  [{'id': 18020433541055266, 'created_at': 15464...       offcorss
# 2  [{'id': 18063949429025469, 'created_at': 15570...       offcorss
# 3  [{'id': 17846744674342193, 'created_at': 15479...       offcorss
# 4  [{'id': 17997127078139199, 'created_at': 15479...       offcorss

# %%
ig_answers = pd.DataFrame([{"rootPost_id":i[0], "parentPost_id":i[1], **j, "brand_username":i[3]} 
                           for i in ig_answers.to_numpy() for j in i[2]])

ig_answers.head()
# Out:
#            rootPost_id  parentPost_id                 id  created_at  \
# 0  1947952244502703605   1.801764e+16  17953738438218094  1546491596
# 1  1948284380053077836   1.790035e+16  18020433541055266  1546491691
# 2  1948805488864773596   1.796902e+16  18063949429025469  1557077648
# 3  1948805488864773596   1.799455e+16  17846744674342193  1547948682
# 4  1948805488864773596   1.788860e+16  17997127078139199  1547948705
#
#                                                 text  \
# 0  Hola @aleja.vasquez911 la camiseta de laya la ...
# 1  Hola @delgadoa953 lo encuentras por $69.900. D...
# 2  @offcorss no es extraña para mí su respuesta.....
# 3  Hola @erika_vanessa_rios te enviaremos un enla...
# 4  Hola @jenny_paez te enviaremos un enlace para ...
#
#                                                owner  likes_count  \
# 0  {'id': '222130816', 'is_verified': True, 'prof...            3
# 1  {'id': '222130816', 'is_verified': True, 'prof...            1
# 2  {'id': '11526821956', 'is_verified': False, 'p...            0
# 3  {'id': '222130816', 'is_verified': True, 'prof...            1
# 4  {'id': '222130816', 'is_verified': True, 'prof...            1
#
#   brand_username
# 0       offcorss
# 1       offcorss
# 2       offcorss
# 3       offcorss
# 4       offcorss

# %%
ig_answers.rename(columns = {
    "id":"response_id",
    "created_at":"time",
    "owner":"username",
    "likes_count": "likes"
}, inplace=True)

ig_answers["time"] = ig_answers.time.apply(datetime.fromtimestamp)
ig_answers["username"] = ig_answers.username.apply(lambda x: x["username"])

ig_answers.head()
# Out:
#            rootPost_id  parentPost_id        response_id                time  \
# 0  1947952244502703605   1.801764e+16  17953738438218094 2019-01-03 04:59:56
# 1  1948284380053077836   1.790035e+16  18020433541055266 2019-01-03 05:01:31
# 2  1948805488864773596   1.796902e+16  18063949429025469 2019-05-05 17:34:08
# 3  1948805488864773596   1.799455e+16  17846744674342193 2019-01-20 01:44:42
# 4  1948805488864773596   1.788860e+16  17997127078139199 2019-01-20 01:45:05
#
#                                                 text  username  likes  \
# 0  Hola @aleja.vasquez911 la camiseta de laya la ...  offcorss      3
# 1  Hola @delgadoa953 lo encuentras por $69.900. D...  offcorss      1
# 2  @offcorss no es extraña para mí su respuesta.....  mapu0831      0
# 3  Hola @erika_vanessa_rios te enviaremos un enla...  offcorss      1
# 4  Hola @jenny_paez te enviaremos un enlace para ...  offcorss      1
#
#   brand_username
# 0       offcorss
# 1       offcorss
# 2       offcorss
# 3       offcorss
# 4       offcorss

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Generating the CSVs
# Now, we are going to split the dataframe `ig_posts` into two CSVs corresponding to the `instagram_posts` and `instagram_reactions` tables. Also, we are going to combine the `ig_comments` and `ig_answers` dataframe into a CSV for the table `instagram_responses`.

# %%
instagram_posts = ig_posts[['post_id', 'text', 'time', 'type', 'is_ad', 'is_video', "post_url", "hashtags", 'brand_username']]
instagram_reactions = ig_posts[['post_id', 'brand_username', 'total_responses', 'total_comments']]

# %%
instagram_posts.to_csv(os.path.join('data', 'instagram_posts.csv'), encoding="utf-8-sig")
instagram_reactions.to_csv(os.path.join('data', 'instagram_reactions.csv'), encoding="utf-8-sig")

# %%
ig_comments["parentPost_id"] = ig_comments.response_id

instagram_responses = pd.concat([ig_answers, ig_comments[['rootPost_id', 'parentPost_id', 'response_id', 'time', 'text', 'username', 'likes', 'brand_username']]])

# %%
instagram_responses.to_csv(os.path.join('data', 'instagram_responses.csv'), encoding="utf-8-sig")
